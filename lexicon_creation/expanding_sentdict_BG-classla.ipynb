# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Loading seed dicts

# %%
with open('positive_seed_BG_ALL_CORR.txt') as f:
    pos_bg = [line.split('\t') for line in f.readlines()][:200]

# %%
with open('negative_seed_BG_ALL_CORR.txt') as f:
    neg_bg = [line.split('\t') for line in f.readlines()][:200]

# %%
words_pos = [line[0] for line in pos_bg]
postags_pos = [line[1] for line in pos_bg]

pos_list = ["-".join(el) for el in zip(words_pos, postags_pos)]

# %%
words_neg = [line[0] for line in neg_bg]
postags_neg = [line[1] for line in neg_bg]

neg_list = ["-".join(el) for el in zip(words_neg, postags_neg)]

# %% [markdown]
# ### Loading GloVe embeddings

# %%
with open('glove/vectors_bg.txt', 'r') as f:
    glove = [line.split('\n')[:-1] for line in f.readlines()]

# %%
glovedict = dict()

for embedding in glove:
    split = embedding[0].split(" ")
    glovedict[split[0]] = [float(number) for number in split[1:]]

# %% [markdown]
# #### Frequency dictionary for word embeddings

# %%
with open('glove/vocab_bg.txt', 'r') as f:
    vocab = [line.split('\n')[:-1] for line in f.readlines()]

# %%
vocab_words = [line[0].split(" ")[0] for line in vocab]
vocab_freqs = [line[0].split(" ")[1] for line in vocab]

vocab_dict = dict(zip(vocab_words, vocab_freqs))

# %% [markdown]
# #### Check if seed words are in vocab - manual correction

# %%
for word in pos_list:
    if word not in list(glovedict.keys()):
        print(word, "MISSING")

# %%
for word in neg_list:
    if word not in list(glovedict.keys()):
        print(word, "MISSING")

# %% [markdown]
# #### Create embedding arrays for positive and negative seed lists
#
# .pop() also removes those from dict in order to prevent perfect matches

# %%
embedding_list_pos = []

for word in pos_list:
    embedding_list_pos.append(glovedict.pop(word))
    
pos_array = np.array(embedding_list_pos)

# %%
embedding_list_neg = []

for word in neg_list:
    embedding_list_neg.append(glovedict.pop(word))
    
neg_array = np.array(embedding_list_neg)

# %%
glovedict.pop('<unk>');

# %% [markdown]
# #### Create GloVe array

# %%
glove_array = np.array(list(glovedict.values()))

# %%
glove_array.shape
# Out:
# (34762, 150)

# %% [markdown]
# ### Compute word scores

# %%
num_seed_words = 200
pos_array = pos_array[:num_seed_words]
neg_array = neg_array[:num_seed_words]

# %%
M_p = glove_array @ pos_array.T 
M_n = glove_array @ neg_array.T

# %%
shape = glove_array.shape

# %%
L_p = (np.linalg.norm(glove_array, axis = 1).reshape([shape[0], 1])) * (np.linalg.norm(pos_array, axis = 1))
L_n = (np.linalg.norm(glove_array, axis = 1).reshape([shape[0], 1])) * (np.linalg.norm(neg_array, axis = 1))

# %%
P = np.sum(M_p / L_p, axis = 1)
Q = np.sum(M_n / L_n, axis = 1)

# %%
S_i = P - Q

# %% [markdown]
# ### Find top and bottom words

# %%
#normalize scores
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler((-1, 1))
norm_score = scaler.fit_transform(S_i.reshape(-1, 1)).flatten()

# %%
#create word and frequency lists based on 
words = np.array([list(glovedict.keys())]).flatten()
freqs = [int(vocab_dict[word]) for word in words]

df = pd.DataFrame({'word': words, 'score':norm_score, 'freq': freqs})

# %%
#frequency limits
df = df[df['freq'] < 15000]
df = df[df['freq'] > 100]

# %%
#splitting word column into lemma and pos columns
df[['lemma', 'pos']] = df['word'].str.split(r'\-+(?=[A-Z])', regex = True, expand = True)

# %%
#filterning out numbers, proper nouns and punctuation
df = df[df['pos'] != 'NUM']
df = df[df['pos'] != 'PROPN']
df = df[df['pos'] != 'PUNCT']
df = df[df['lemma'].str.isnumeric() == False]

# %%
#sorting by score 
sorted_df = df.sort_values(['score'])

# %% [markdown]
# ### Positive expansion

# %%
#first 500 most positive words
pos_expansion = sorted_df[-500:].iloc[::-1]

# %%
with pd.option_context('display.max_rows', None,
                       'display.max_columns', None,
                       'display.precision', 3,
                       ):
    print(pos_expansion)
# Out:
#                            word  score   freq                  lemma    pos
# 596                осигуря-VERB  1.000   5405                осигуря   VERB
# 632             гарантирам-VERB  0.967   5086             гарантирам   VERB
# 601                  заедно-ADV  0.893   5369                 заедно    ADV
# 324               подкрепа-NOUN  0.891  10529               подкрепа   NOUN
# 2966               пожелая-VERB  0.875    673                пожелая   VERB
# 317                   нека-PART  0.833  10676                   нека   PART
# 1489           гарантиране-NOUN  0.815   1817            гарантиране   NOUN
# 711                 усилие-NOUN  0.800   4525                 усилие   NOUN
# 1728              разчитам-VERB  0.794   1473               разчитам   VERB
# 241             давам-(се)-VERB  0.790  14123             давам-(се)   VERB
# 724              приоритет-NOUN  0.781   4429              приоритет   NOUN
# 1390           запазя-(се)-VERB  0.780   1996            запазя-(се)   VERB
# 931             осигурявам-VERB  0.773   3311             осигурявам   VERB
# 682            намеря-(се)-VERB  0.769   4763            намеря-(се)   VERB
# 268               необходим-ADJ  0.760  12721              необходим    ADJ
# 4266             пълноценен-ADJ  0.749    360             пълноценен    ADJ
# 849                 избера-VERB  0.745   3745                 избера   VERB
# 231                 работя-VERB  0.740  14676                 работя   VERB
# 1710                  нужен-ADJ  0.737   1497                  нужен    ADJ
# 3421            грижа-(се)-VERB  0.734    522             грижа-(се)   VERB
# 1056              партньор-NOUN  0.731   2870               партньор   NOUN
# 1597                  равен-ADJ  0.730   1666                  равен    ADJ
# 895             инициатива-NOUN  0.729   3501             инициатива   NOUN
# 4249              оптимален-ADJ  0.726    362              оптимален    ADJ
# 3024             отстоявам-VERB  0.723    651              отстоявам   VERB
# 618              достатъчно-ADV  0.722   5181             достатъчно    ADV
# 875                желание-NOUN  0.719   3629                желание   NOUN
# 3666            съдействам-VERB  0.716    461             съдействам   VERB
# 2249            заслужавам-VERB  0.707   1003             заслужавам   VERB
# 823                  желая-VERB  0.706   3880                  желая   VERB
# 1222                учител-NOUN  0.706   2386                 учител   NOUN
# 7748             ротационен-ADJ  0.705    120             ротационен    ADJ
# 600             предоставя-VERB  0.704   5375             предоставя   VERB
# 3233             балансирам-ADJ  0.703    578             балансирам    ADJ
# 923                   воля-NOUN  0.702   3344                   воля   NOUN
# 2168               призова-VERB  0.702   1069                призова   VERB
# 431             надявам-се-VERB  0.701   7903             надявам-се   VERB
# 4429            дестинация-NOUN  0.692    338             дестинация   NOUN
# 309                 получа-VERB  0.691  11018                 получа   VERB
# 8076             подсигуря-VERB  0.687    110              подсигуря   VERB
# 1377            реализация-NOUN  0.687   2032             реализация   NOUN
# 461                позиция-NOUN  0.684   7061                позиция   NOUN
# 230                  всеки-PRON  0.682  14814                  всеки   PRON
# 384               предложа-VERB  0.681   9097               предложа   VERB
# 1308              съвместен-ADJ  0.681   2186              съвместен    ADJ
# 1688      представителство-NOUN  0.681   1518       представителство   NOUN
# 1137              независим-ADJ  0.681   2623              независим    ADJ
# 2553                 седна-VERB  0.680    835                  седна   VERB
# 671                  заявя-VERB  0.677   4832                  заявя   VERB
# 934             подготовка-NOUN  0.675   3291             подготовка   NOUN
# 696             върна-(се)-VERB  0.675   4624             върна-(се)   VERB
# 628             изграждане-NOUN  0.669   5117             изграждане   NOUN
# 812               постигна-VERB  0.669   3939               постигна   VERB
# 420               продължа-VERB  0.668   8143               продължа   VERB
# 1584           радвам-(се)-VERB  0.668   1676            радвам-(се)   VERB
# 850                  научен-ADJ  0.666   3730                 научен    ADJ
# 2660           приветствам-VERB  0.666    790            приветствам   VERB
# 2152               достъпен-ADJ  0.665   1081               достъпен    ADJ
# 2674              прозрачен-ADJ  0.662    785              прозрачен    ADJ
# 2299              съвместно-ADV  0.661    971              съвместно    ADV
# 1686          обединя-(се)-VERB  0.661   1519           обединя-(се)   VERB
# 1341              адекватен-ADJ  0.660   2114              адекватен    ADJ
# 568                култура-NOUN  0.660   5688                култура   NOUN
# 240                  мисля-VERB  0.660  14160                  мисля   VERB
# 3818                 кауза-NOUN  0.660    434                  кауза   NOUN
# 1539         подготвя-(се)-VERB  0.660   1745          подготвя-(се)   VERB
# 1048              отговорен-ADJ  0.660   2904              отговорен    ADJ
# 1332       председателство-NOUN  0.657   2135        председателство   NOUN
# 6469             толерантен-ADJ  0.657    171             толерантен    ADJ
# 390                 следва-VERB  0.657   8744                 следва   VERB
# 501           професионален-ADJ  0.656   6436          професионален    ADJ
# 1264                диалог-NOUN  0.655   2291                 диалог   NOUN
# 983             убедя-(се)-VERB  0.652   3103             убедя-(се)   VERB
# 1419             постигане-NOUN  0.651   1944              постигане   NOUN
# 2967              изработя-VERB  0.650    672               изработя   VERB
# 1920           устойчивост-NOUN  0.649   1274            устойчивост   NOUN
# 1026                  важно-ADV  0.648   2953                  важно    ADV
# 1211           насоча-(се)-VERB  0.648   2416            насоча-(се)   VERB
# 479                очаквам-VERB  0.647   6725                очаквам   VERB
# 244                   добре-ADV  0.646  13900                  добре    ADV
# 1741             максимално-ADV  0.645   1458             максимално    ADV
# 1689           насърчаване-NOUN  0.644   1517            насърчаване   NOUN
# 3221             пожелавам-VERB  0.644    583              пожелавам   VERB
# 3469              отговарям-ADJ  0.644    510              отговарям    ADJ
# 752             провеждане-NOUN  0.644   4238             провеждане   NOUN
# 1149                 грижа-NOUN  0.643   2570                  грижа   NOUN
# 260                  взема-VERB  0.642  13250                  взема   VERB
# 1060             капацитет-NOUN  0.642   2863              капацитет   NOUN
# 1798               устойчив-ADJ  0.642   1401               устойчив    ADJ
# 1134                  екип-NOUN  0.642   2627                   екип   NOUN
# 1496             предоставя-ADJ  0.641   1811             предоставя    ADJ
# 318                    наш-PRON  0.641  10615                    наш   PRON
# 1518                 напред-ADV  0.640   1773                 напред    ADV
# 1461               изградя-VERB  0.639   1857                изградя   VERB
# 1273                вярвам-VERB  0.639   2274                 вярвам   VERB
# 861                собствен-ADJ  0.639   3681               собствен    ADJ
# 2245                положа-VERB  0.638   1005                 положа   VERB
# 1640                 юрист-NOUN  0.638   1590                  юрист   NOUN
# 928                    млад-ADJ  0.638   3321                   млад    ADJ
# 4637             информирам-ADJ  0.637    314             информирам    ADJ
# 1751             концепция-NOUN  0.637   1447              концепция   NOUN
# 6512            равноправен-ADJ  0.636    169            равноправен    ADJ
# 325              становище-NOUN  0.635  10489              становище   NOUN
# 1669           кандидатура-NOUN  0.633   1541            кандидатура   NOUN
# 7721         безпристрастен-ADJ  0.631    120         безпристрастен    ADJ
# 967            демократичен-ADJ  0.631   3163           демократичен    ADJ
# 468               качество-NOUN  0.631   6946               качество   NOUN
# 681                   идея-NOUN  0.631   4770                   идея   NOUN
# 7925                 кураж-NOUN  0.629    114                  кураж   NOUN
# 832            предоставям-VERB  0.626   3838            предоставям   VERB
# 302                  рамка-NOUN  0.626  11220                  рамка   NOUN
# 2092             запазване-NOUN  0.626   1128              запазване   NOUN
# 3452             стремя-се-VERB  0.626    515              стремя-се   VERB
# 840             правосъдие-NOUN  0.626   3806             правосъдие   NOUN
# 323            осигуряване-NOUN  0.625  10539            осигуряване   NOUN
# 1195            разполагам-VERB  0.625   2453             разполагам   VERB
# 2220             пазя-(се)-VERB  0.624   1026              пазя-(се)   VERB
# 602                 мнение-NOUN  0.624   5362                 мнение   NOUN
# 2185                  шанс-NOUN  0.623   1055                   шанс   NOUN
# 289         представя-(се)-VERB  0.619  11649         представя-(се)   VERB
# 712          запозная-(се)-VERB  0.619   4519          запозная-(се)   VERB
# 1090                стъпка-NOUN  0.619   2791                 стъпка   NOUN
# 407                участие-NOUN  0.618   8371                участие   NOUN
# 898            покажа-(се)-VERB  0.617   3486            покажа-(се)   VERB
# 299                 смятам-VERB  0.615  11357                 смятам   VERB
# 694           ползвам-(се)-VERB  0.615   4647           ползвам-(се)   VERB
# 472                   база-NOUN  0.614   6814                   база   NOUN
# 454               участвам-VERB  0.612   7285               участвам   VERB
# 927                  кратък-ADJ  0.612   3323                 кратък    ADJ
# 948                 бъдеще-NOUN  0.611   3248                 бъдеще   NOUN
# 5022          съхраня-(се)-VERB  0.611    273           съхраня-(се)   VERB
# 2293                модерен-ADJ  0.610    972                модерен    ADJ
# 1316           помоля-(се)-VERB  0.608   2165            помоля-(се)   VERB
# 520            обърна-(се)-VERB  0.608   6179            обърна-(се)   VERB
# 1044                  готов-ADJ  0.606   2911                  готов    ADJ
# 5178            отдам-(се)-VERB  0.606    257             отдам-(се)   VERB
# 1583                завися-VERB  0.605   1676                 завися   VERB
# 278               внимание-NOUN  0.603  12198               внимание   NOUN
# 635                проведа-VERB  0.601   5068                проведа   VERB
# 588             изпълнявам-VERB  0.601   5548             изпълнявам   VERB
# 386              създаване-NOUN  0.600   8807              създаване   NOUN
# 1336                     ѝ-PRON  0.598   2128                      ѝ   PRON
# 320                  техен-PRON  0.597  10565                  техен   PRON
# 362                    висш-ADJ  0.596   9562                   висш    ADJ
# 854         сътрудничество-NOUN  0.591   3709         сътрудничество   NOUN
# 841             отида-(си)-VERB  0.591   3794             отида-(си)   VERB
# 1126                  роля-NOUN  0.591   2671                   роля   NOUN
# 1357           развия-(се)-VERB  0.590   2082            развия-(се)   VERB
# 1493             готовност-NOUN  0.590   1814              готовност   NOUN
# 8227                 почтен-ADJ  0.590    106                 почтен    ADJ
# 1148              гаранция-NOUN  0.589   2570               гаранция   NOUN
# 516                    поне-ADV  0.589   6230                   поне    ADV
# 1076           обединя-(се)-ADJ  0.588   2827           обединя-(се)    ADJ
# 676            изразя-(се)-VERB  0.587   4802            изразя-(се)   VERB
# 5428          равнопоставен-ADJ  0.587    235          равнопоставен    ADJ
# 6443                творец-NOUN  0.584    172                 творец   NOUN
# 844            действително-ADV  0.582   3782           действително    ADV
# 276                   дама-NOUN  0.582  12436                   дама   NOUN
# 3631              личностен-ADJ  0.581    471              личностен    ADJ
# 2049         последователен-ADJ  0.581   1160         последователен    ADJ
# 665               единствен-ADJ  0.580   4893              единствен    ADJ
# 3949               съюзник-NOUN  0.580    409                съюзник   NOUN
# 2230                активно-ADV  0.578   1015                активно    ADV
# 402               кандидат-NOUN  0.578   8518               кандидат   NOUN
# 2176             гарантирам-ADJ  0.578   1060             гарантирам    ADJ
# 1872                 визия-NOUN  0.578   1316                  визия   NOUN
# 1333              академия-NOUN  0.577   2133               академия   NOUN
# 2143           консултация-NOUN  0.577   1084            консултация   NOUN
# 233             изпълнение-NOUN  0.577  14655             изпълнение   NOUN
# 685           изпълня-(се)-VERB  0.575   4736           изпълня-(се)   VERB
# 1117                активен-ADJ  0.575   2688                активен    ADJ
# 2739        професионалист-NOUN  0.575    757         професионалист   NOUN
# 2388           перспектива-NOUN  0.574    925            перспектива   NOUN
# 3398          подготвя-(се)-ADJ  0.573    529          подготвя-(се)    ADJ
# 1038              опазване-NOUN  0.573   2923               опазване   NOUN
# 1557                   бърз-ADJ  0.572   1721                   бърз    ADJ
# 763               отбележа-VERB  0.572   4158               отбележа   VERB
# 645                  винаги-ADV  0.571   4985                 винаги    ADV
# 2148            уверя-(се)-VERB  0.571   1083             уверя-(се)   VERB
# 5303             благодарен-ADJ  0.570    245             благодарен    ADJ
# 2434          конструктивен-ADJ  0.569    897          конструктивен    ADJ
# 6200               способен-ADJ  0.569    184               способен    ADJ
# 521                 център-NOUN  0.569   6155                 център   NOUN
# 4006          благодарност-NOUN  0.569    400           благодарност   NOUN
# 1071                 длъжен-ADJ  0.569   2835                 длъжен    ADJ
# 331                    име-NOUN  0.569  10358                    име   NOUN
# 1408           събера-(се)-VERB  0.569   1959            събера-(се)   VERB
# 394               отговоря-VERB  0.568   8683               отговоря   VERB
# 838                 обсъдя-VERB  0.568   3816                 обсъдя   VERB
# 8292            изявя-(се)-VERB  0.568    104             изявя-(се)   VERB
# 7245            съблюдавам-VERB  0.568    137             съблюдавам   VERB
# 1605          реформаторски-ADJ  0.568   1649          реформаторски    ADJ
# 334                съгласно-ADP  0.568  10253               съгласно    ADP
# 1571               ценност-NOUN  0.567   1697                ценност   NOUN
# 1303                 получа-ADJ  0.566   2195                 получа    ADJ
# 1028              съгласие-NOUN  0.566   2951               съгласие   NOUN
# 557               специален-ADJ  0.566   5782              специален    ADJ
# 488                 начало-NOUN  0.566   6655                 начало   NOUN
# 1517            заема-(се)-VERB  0.565   1779             заема-(се)   VERB
# 1247                взимам-VERB  0.565   2319                 взимам   VERB
# 1536         функциониране-NOUN  0.564   1750          функциониране   NOUN
# 339                  човек-NOUN  0.563  10111                  човек   NOUN
# 1816               студент-NOUN  0.563   1385                студент   NOUN
# 415                 колкото-ADV  0.563   8267                колкото    ADV
# 1429         съобразя-(се)-VERB  0.563   1921          съобразя-(се)   VERB
# 1005           представяне-NOUN  0.563   3026            представяне   NOUN
# 525                  народ-NOUN  0.562   6115                  народ   NOUN
# 1006                 работя-ADJ  0.561   3024                 работя    ADJ
# 810          определя-(се)-VERB  0.561   3953          определя-(се)   VERB
# 1989             изложение-NOUN  0.561   1209              изложение   NOUN
# 357                 работен-ADJ  0.560   9652                работен    ADJ
# 856             специалист-NOUN  0.560   3704             специалист   NOUN
# 329             институция-NOUN  0.560  10367             институция   NOUN
# 1825           реализиране-NOUN  0.560   1381            реализиране   NOUN
# 372                започна-VERB  0.560   9407                започна   VERB
# 1406              експертен-ADJ  0.559   1960              експертен    ADJ
# 4841          самочувствие-NOUN  0.559    291           самочувствие   NOUN
# 2235          обезпечаване-NOUN  0.558   1012           обезпечаване   NOUN
# 1823                  гост-NOUN  0.558   1381                   гост   NOUN
# 1367         развивам-(се)-VERB  0.557   2045          развивам-(се)   VERB
# 1087             максимален-ADJ  0.556   2796             максимален    ADJ
# 1551            потребност-NOUN  0.556   1730             потребност   NOUN
# 1937        разработя-(се)-VERB  0.556   1255         разработя-(се)   VERB
# 974             призовавам-VERB  0.556   3141             призовавам   VERB
# 1201               депутат-NOUN  0.555   2443                депутат   NOUN
# 500                  наука-NOUN  0.555   6445                  наука   NOUN
# 6449        благосъстояние-NOUN  0.555    171         благосъстояние   NOUN
# 1287                  бъдещ-ADJ  0.554   2239                  бъдещ    ADJ
# 2276                знание-NOUN  0.553    984                 знание   NOUN
# 3893                излъча-VERB  0.552    418                 излъча   VERB
# 1398             консенсус-NOUN  0.552   1970              консенсус   NOUN
# 1673                 избера-ADJ  0.552   1535                 избера    ADJ
# 1008                задача-NOUN  0.552   3016                 задача   NOUN
# 4323             ангажирам-VERB  0.552    352              ангажирам   VERB
# 1399                статут-NOUN  0.551   1968                 статут   NOUN
# 2394             допринеса-VERB  0.551    922              допринеса   VERB
# 272              видя-(се)-VERB  0.551  12518              видя-(се)   VERB
# 760               изисквам-VERB  0.550   4185               изисквам   VERB
# 1135       реализирам-(се)-VERB  0.550   2627        реализирам-(се)   VERB
# 443              отговарям-VERB  0.548   7559              отговарям   VERB
# 606               обучение-NOUN  0.547   5312               обучение   NOUN
# 1431        настоявам-(се)-VERB  0.546   1918         настоявам-(се)   VERB
# 1161             намерение-NOUN  0.546   2531              намерение   NOUN
# 7943                артист-NOUN  0.546    113                 артист   NOUN
# 609               българин-NOUN  0.545   5285               българин   NOUN
# 5144         приемственост-NOUN  0.545    260          приемственост   NOUN
# 833                  среща-NOUN  0.545   3833                  среща   NOUN
# 539                  нужда-NOUN  0.545   5983                  нужда   NOUN
# 1387            поддържане-NOUN  0.545   2007             поддържане   NOUN
# 559                 посока-NOUN  0.544   5769                 посока   NOUN
# 7263              образовам-ADJ  0.544    136              образовам    ADJ
# 4298            изразяване-NOUN  0.544    355             изразяване   NOUN
# 2685               потърся-VERB  0.543    780                потърся   VERB
# 1046                 единен-ADJ  0.543   2908                 единен    ADJ
# 1510                  неин-PRON  0.543   1789                   неин   PRON
# 1437             сдружение-NOUN  0.542   1896              сдружение   NOUN
# 3255          утвърдя-(се)-VERB  0.542    570           утвърдя-(се)   VERB
# 5448                  вяра-NOUN  0.542    233                   вяра   NOUN
# 1763          подобря-(се)-VERB  0.541   1435           подобря-(се)   VERB
# 594                  дойда-VERB  0.540   5468                  дойда   VERB
# 6187               домакин-NOUN  0.539    184                домакин   NOUN
# 2295          партньорство-NOUN  0.538    972           партньорство   NOUN
# 2608                  учен-NOUN  0.538    813                   учен   NOUN
# 762                 дуплик-NOUN  0.538   4162                 дуплик   NOUN
# 2730             формиране-NOUN  0.537    761              формиране   NOUN
# 1182           ръководител-NOUN  0.537   2473            ръководител   NOUN
# 3032          консултативен-ADJ  0.536    647          консултативен    ADJ
# 1904            притежавам-VERB  0.536   1287             притежавам   VERB
# 5264              командир-NOUN  0.536    249               командир   NOUN
# 2768           предам-(се)-VERB  0.535    743            предам-(се)   VERB
# 1580           прозрачност-NOUN  0.535   1685            прозрачност   NOUN
# 4692                утрешен-ADJ  0.535    309                утрешен    ADJ
# 1003                спортен-ADJ  0.535   3027                спортен    ADJ
# 514                  остана-ADJ  0.535   6240                 остана    ADJ
# 2742             авторитет-NOUN  0.535    755              авторитет   NOUN
# 1120              спазване-NOUN  0.535   2683               спазване   NOUN
# 2211               виждане-NOUN  0.535   1034                виждане   NOUN
# 722      осъществявам-(се)-VERB  0.534   4436      осъществявам-(се)   VERB
# 1602             омбудсман-NOUN  0.534   1654              омбудсман   NOUN
# 416                    чуя-VERB  0.534   8256                    чуя   VERB
# 2025                   дух-NOUN  0.534   1181                    дух   NOUN
# 4340               прецизен-ADJ  0.533    350               прецизен    ADJ
# 2990          утвърждаване-NOUN  0.533    660           утвърждаване   NOUN
# 251                  госпож-ADJ  0.532  13634                 госпож    ADJ
# 1209          стратегически-ADJ  0.532   2422          стратегически    ADJ
# 578              стратегия-NOUN  0.532   5604              стратегия   NOUN
# 4739          издигна-(се)-VERB  0.531    302           издигна-(се)   VERB
# 1656                 ключов-ADJ  0.531   1569                 ключов    ADJ
# 1702               споделя-VERB  0.529   1507                споделя   VERB
# 4213                 вложа-VERB  0.528    367                  вложа   VERB
# 527              земеделие-NOUN  0.527   6100              земеделие   NOUN
# 3069              обезпеча-VERB  0.527    629               обезпеча   VERB
# 4157             докторант-NOUN  0.527    374              докторант   NOUN
# 3693                родина-NOUN  0.526    457                 родина   NOUN
# 7129            възбуждане-NOUN  0.525    141             възбуждане   NOUN
# 1814               коректен-ADJ  0.525   1386               коректен    ADJ
# 1466            патриотичен-ADJ  0.524   1847            патриотичен    ADJ
# 1323               възможно-ADV  0.524   2146               възможно    ADV
# 6824           приобщаване-NOUN  0.524    154            приобщаване   NOUN
# 1807              съобразно-ADV  0.523   1394              съобразно    ADV
# 657           позволя-(си)-VERB  0.523   4947           позволя-(си)   VERB
# 4032           конференция-NOUN  0.523    395            конференция   NOUN
# 2563                акцент-NOUN  0.522    827                 акцент   NOUN
# 2803          преподавател-NOUN  0.521    731           преподавател   NOUN
# 8116                  почтя-ADJ  0.520    109                  почтя    ADJ
# 2428                призив-NOUN  0.519    901                 призив   NOUN
# 494                 минута-NOUN  0.519   6507                 минута   NOUN
# 774                експерт-NOUN  0.519   4128                експерт   NOUN
# 398              използвам-VERB  0.519   8596              използвам   VERB
# 893                  армия-NOUN  0.517   3504                  армия   NOUN
# 1978         ръководя-(се)-VERB  0.517   1221          ръководя-(се)   VERB
# 3410           спокойствие-NOUN  0.517    526            спокойствие   NOUN
# 490              обсъждане-NOUN  0.517   6635              обсъждане   NOUN
# 1244               попитам-VERB  0.516   2322                попитам   VERB
# 890                  веднъж-ADV  0.516   3511                 веднъж    ADV
# 4312       професионализъм-NOUN  0.516    354        професионализъм   NOUN
# 5769            християнски-ADJ  0.516    211            християнски    ADJ
# 1477              специално-ADV  0.515   1833              специално    ADV
# 716            вицепремиер-NOUN  0.515   4486            вицепремиер   NOUN
# 444            финансиране-NOUN  0.514   7499            финансиране   NOUN
# 981                спазвам-VERB  0.513   3112                спазвам   VERB
# 237              парламент-NOUN  0.513  14542              парламент   NOUN
# 2015              формирам-VERB  0.513   1191               формирам   VERB
# 249                интерес-NOUN  0.512  13703                интерес   NOUN
# 879           обръщам-(се)-VERB  0.511   3586           обръщам-(се)   VERB
# 2140           повиша-(се)-VERB  0.510   1088            повиша-(се)   VERB
# 8146                 облик-NOUN  0.510    108                  облик   NOUN
# 1438               закрила-NOUN  0.510   1895                закрила   NOUN
# 1564          заинтересован-ADJ  0.509   1711          заинтересован    ADJ
# 950         възнаграждение-NOUN  0.508   3236         възнаграждение   NOUN
# 1129               дуплика-NOUN  0.508   2652                дуплика   NOUN
# 1100           изкажа-(се)-VERB  0.508   2735            изкажа-(се)   VERB
# 518                 ресурс-NOUN  0.507   6220                 ресурс   NOUN
# 3262           стимулиране-NOUN  0.507    567            стимулиране   NOUN
# 1717                месечен-ADJ  0.506   1491                месечен    ADJ
# 2981              безопасен-ADJ  0.506    664              безопасен    ADJ
# 2084        ангажирам-(се)-VERB  0.506   1134         ангажирам-(се)   VERB
# 380                училище-NOUN  0.506   9262                училище   NOUN
# 883              семейство-NOUN  0.505   3563              семейство   NOUN
# 1314           туристически-ADJ  0.505   2167           туристически    ADJ
# 755                  писмен-ADJ  0.504   4215                 писмен    ADJ
# 714                туризъм-NOUN  0.503   4489                туризъм   NOUN
# 1549                 хубаво-ADV  0.503   1733                 хубаво    ADV
# 1737       възстановя-(се)-VERB  0.503   1463        възстановя-(се)   VERB
# 2446                  влог-NOUN  0.502    894                   влог   NOUN
# 295                   труд-NOUN  0.502  11513                   труд   NOUN
# 4066            консултант-NOUN  0.501    390             консултант   NOUN
# 255                     пак-ADV  0.500  13473                    пак    ADV
# 1981               проектен-ADJ  0.500   1215               проектен    ADJ
# 2000           организирам-VERB  0.500   1198            организирам   VERB
# 640                  търся-VERB  0.499   5014                  търся   VERB
# 411                   освен-ADP  0.499   8312                  освен    ADP
# 1092               родител-NOUN  0.499   2774                родител   NOUN
# 2207             интегрирам-ADJ  0.499   1038             интегрирам    ADJ
# 867          включвам-(се)-VERB  0.499   3667          включвам-(се)   VERB
# 1566               помисля-VERB  0.498   1708                помисля   VERB
# 281                   първо-ADV  0.498  12113                  първо    ADV
# 1337                охрана-NOUN  0.498   2125                 охрана   NOUN
# 670              президент-NOUN  0.498   4850              президент   NOUN
# 852         възстановяване-NOUN  0.498   3723         възстановяване   NOUN
# 5985           добронамерен-ADJ  0.498    196           добронамерен    ADJ
# 607             ангажимент-NOUN  0.497   5302             ангажимент   NOUN
# 746               значение-NOUN  0.497   4264               значение   NOUN
# 1012                редовен-ADJ  0.497   3005                редовен    ADJ
# 551         инфраструктура-NOUN  0.497   5853         инфраструктура   NOUN
# 655            включа-(се)-VERB  0.497   4956            включа-(се)   VERB
# 382                  където-ADV  0.496   9169                 където    ADV
# 4822             репутация-NOUN  0.496    293              репутация   NOUN
# 3436           изчерпателен-ADJ  0.496    518           изчерпателен    ADJ
# 3954               стремеж-NOUN  0.496    408                стремеж   NOUN
# 483                 достъп-NOUN  0.496   6674                 достъп   NOUN
# 2203            категоричен-ADJ  0.496   1042            категоричен    ADJ
# 2330            съгласувам-VERB  0.496    954             съгласувам   VERB
# 1224            държа-(се)-VERB  0.494   2380             държа-(се)   VERB
# 471                енергиен-ADJ  0.494   6865               енергиен    ADJ
# 993                почивка-NOUN  0.494   3057                почивка   NOUN
# 6357             сертифика-NOUN  0.494    176              сертифика   NOUN
# 831            запиша-(се)-VERB  0.494   3840            запиша-(се)   VERB
# 6542            ползотворен-ADJ  0.493    167            ползотворен    ADJ
# 2069            инвестирам-VERB  0.493   1145             инвестирам   VERB
# 5668             държавник-NOUN  0.493    217              държавник   NOUN
# 693                постъпя-VERB  0.492   4648                постъпя   VERB
# 6631                  утро-NOUN  0.492    163                   утро   NOUN
# 306                финанси-NOUN  0.492  11092                финанси   NOUN
# 1391               какъвто-PRON  0.492   1994                какъвто   PRON
# 3556            традиционен-ADJ  0.492    488            традиционен    ADJ
# 997             повишаване-NOUN  0.491   3045             повишаване   NOUN
# 269                     да-INTJ  0.491  12687                     да   INTJ
# 3026                офицер-NOUN  0.491    649                 офицер   NOUN
# 4383                посетя-VERB  0.491    345                 посетя   VERB
# 321                отбрана-NOUN  0.490  10564                отбрана   NOUN
# 5198            консенсусен-ADJ  0.490    255            консенсусен    ADJ
# 3523              привлека-VERB  0.490    495               привлека   VERB
# 434            международен-ADJ  0.490   7871           международен    ADJ
# 1396        изразявам-(се)-VERB  0.489   1974         изразявам-(се)   VERB
# 656             инвестиция-NOUN  0.489   4951             инвестиция   NOUN
# 8193          изследовател-NOUN  0.489    107           изследовател   NOUN
# 2613                 мисия-NOUN  0.488    810                  мисия   NOUN
# 4667              търпение-NOUN  0.488    311               търпение   NOUN
# 6964            авторитетен-ADJ  0.488    148            авторитетен    ADJ
# 2266        мотивирам-(се)-VERB  0.488    988         мотивирам-(се)   VERB
# 2118               полагам-VERB  0.487   1105                полагам   VERB
# 258                  избор-NOUN  0.487  13452                  избор   NOUN
# 1160                  блок-NOUN  0.487   2535                   блок   NOUN
# 535         определям-(се)-VERB  0.486   6029         определям-(се)   VERB
# 1011               нормален-ADJ  0.486   3006               нормален    ADJ
# 1136                 поема-VERB  0.486   2625                  поема   VERB
# 1680             разбиране-NOUN  0.486   1529              разбиране   NOUN
# 2515              апелирам-VERB  0.485    855               апелирам   VERB
# 4740             наема-(се)-ADJ  0.485    302             наема-(се)    ADJ
# 3874                 сърце-NOUN  0.484    422                  сърце   NOUN
# 5712               достойно-ADV  0.484    214               достойно    ADV
# 2479                  клуб-NOUN  0.483    878                   клуб   NOUN
# 3846               коридор-NOUN  0.483    427                коридор   NOUN
# 2471            библиотека-NOUN  0.483    881             библиотека   NOUN
# 599              механизъм-NOUN  0.483   5378              механизъм   NOUN
# 335                   личен-ADJ  0.483  10228                  личен    ADJ
# 576                  нито-CCONJ  0.482   5614                   нито  CCONJ
# 782                 мандат-NOUN  0.482   4073                 мандат   NOUN
# 2430         кандидатствам-VERB  0.482    899          кандидатствам   VERB
# 6679            задграничен-ADJ  0.482    160            задграничен    ADJ
# 995              избирател-NOUN  0.481   3053              избирател   NOUN
# 2391              синдикат-NOUN  0.481    924               синдикат   NOUN
# 2477           отделя-(се)-VERB  0.481    879            отделя-(се)   VERB
# 330                 защита-NOUN  0.480  10364                 защита   NOUN
# 2466            възпитание-NOUN  0.479    885             възпитание   NOUN
# 509                заплата-NOUN  0.479   6282                заплата   NOUN
# 360               съответно-ADV  0.478   9579              съответно    ADV
# 1085         осъществяване-NOUN  0.478   2801          осъществяване   NOUN
# 962             информирам-VERB  0.477   3172             информирам   VERB
# 697               институт-NOUN  0.477   4621               институт   NOUN
# 963            свърша-(се)-VERB  0.477   3172            свърша-(се)   VERB
# 5412        парламентарист-NOUN  0.477    236         парламентарист   NOUN
# 4961        изследователски-ADJ  0.477    278        изследователски    ADJ
# 7393                дворец-NOUN  0.476    131                 дворец   NOUN
# 1353         разпределение-NOUN  0.476   2089          разпределение   NOUN
# 4808                гарант-NOUN  0.475    294                 гарант   NOUN
# 4214              замествам-ADJ  0.475    367              замествам    ADJ
# 1261           направление-NOUN  0.475   2295            направление   NOUN
# 1054           опитам-(се)-VERB  0.475   2879            опитам-(се)   VERB
# 1228                 съдия-NOUN  0.474   2372                  съдия   NOUN
# 506                   госпожа-X  0.474   6343                госпожа      X
# 497                    ваш-PRON  0.474   6482                    ваш   PRON
# 1600                 нация-NOUN  0.472   1655                  нация   NOUN
# 3562          върховенство-NOUN  0.472    486           върховенство   NOUN
# 901                 вземам-VERB  0.472   3478                 вземам   VERB
# 245                    чрез-ADP  0.472  13891                   чрез    ADP
# 2183                  целев-ADJ  0.471   1057                  целев    ADJ
# 1275             необходимо-ADV  0.471   2269             необходимо    ADV
# 1051             подчертая-VERB  0.471   2892              подчертая   VERB
# 921                 подход-NOUN  0.471   3352                 подход   NOUN
# 3520                  базов-ADJ  0.471    495                  базов    ADJ
# 1797              планирам-VERB  0.471   1401               планирам   VERB
# 1140                  после-ADV  0.471   2610                  после    ADV
# 7000             отечество-NOUN  0.470    147              отечество   NOUN
# 6513                   син-NOUN  0.470    169                    син   NOUN
# 1389                 молба-NOUN  0.470   2004                  молба   NOUN
# 1886                 спазя-VERB  0.469   1306                  спазя   VERB
# 1225               общност-NOUN  0.469   2380                общност   NOUN
# 1171         представя-(се)-ADJ  0.469   2514         представя-(се)    ADJ
# 842                  спорт-NOUN  0.469   3793                  спорт   NOUN
# 2619                   мъж-NOUN  0.469    807                    мъж   NOUN
# 1042               избирам-VERB  0.469   2914                избирам   VERB
# 2857                 сесия-NOUN  0.468    712                  сесия   NOUN
# 3947            свързаност-NOUN  0.468    409             свързаност   NOUN
# 6858            пълноправен-ADJ  0.467    153            пълноправен    ADJ
# 1210               чужбина-NOUN  0.467   2420                чужбина   NOUN
# 1546               преценя-VERB  0.467   1734                преценя   VERB
# 405              икономика-NOUN  0.467   8386              икономика   NOUN
# 4644  научноизследователски-ADJ  0.466    313  научноизследователски    ADJ
# 485                  внеса-VERB  0.466   6667                  внеса   VERB
# 1754          военнослужещ-NOUN  0.466   1444           военнослужещ   NOUN
# 1809           първоначален-ADJ  0.466   1393           първоначален    ADJ
# 259                  дебат-NOUN  0.466  13344                  дебат   NOUN
# 2813       задължавам-(се)-VERB  0.465    727        задължавам-(се)   VERB
# 2748                 служа-VERB  0.465    753                  служа   VERB
# 1455             асоциация-NOUN  0.464   1867              асоциация   NOUN
# 991          откривам-(се)-VERB  0.464   3065          откривам-(се)   VERB
# 3354             мотивация-NOUN  0.464    539              мотивация   NOUN
# 292                 област-NOUN  0.463  11610                 област   NOUN
# 1386                 следя-VERB  0.463   2018                  следя   VERB
# 1508       председателствам-ADJ  0.463   1792       председателствам    ADJ
# 4533               румънски-ADJ  0.463    326               румънски    ADJ
# 2532             продукция-NOUN  0.462    847              продукция   NOUN
# 2442                 копие-NOUN  0.462    895                  копие   NOUN
# 2721              изкуство-NOUN  0.461    764               изкуство   NOUN
# 3049            постижение-NOUN  0.461    636             постижение   NOUN
# 4843                 финал-NOUN  0.461    291                  финал   NOUN
# 1248               цялостен-ADJ  0.461   2319               цялостен    ADJ
# 406                   висок-ADJ  0.461   8380                  висок    ADJ
# 5790             пожелание-NOUN  0.460    209              пожелание   NOUN
# 423                 оценка-NOUN  0.460   8041                 оценка   NOUN
# 814               професор-NOUN  0.460   3927               професор   NOUN
# 998                следвам-VERB  0.460   3045                следвам   VERB
# 6316                 кратко-ADV  0.460    178                 кратко    ADV
# 2189           комуникация-NOUN  0.460   1052            комуникация   NOUN
# 1478                 майка-NOUN  0.459   1832                  майка   NOUN
# 2179              изслушам-VERB  0.459   1059               изслушам   VERB
# 889                  детски-ADJ  0.459   3517                 детски    ADJ
# 690             задам-(се)-VERB  0.459   4688             задам-(се)   VERB

# %%
#save to file
pos_expansion.to_csv('positive_expansion_BG.csv')

# %% [markdown]
# ### Negative expansion

# %%
neg_expansion = sorted_df[:500]

# %%
with pd.option_context('display.max_rows', None,
                       'display.max_columns', None,
                       'display.precision', 3,
                       ):
    print(neg_expansion)
# Out:
#                          word  score  freq               lemma   pos
# 7891          причинявам-VERB -0.827   115          причинявам  VERB
# 4441             очевиден-ADJ -0.791   337            очевиден   ADJ
# 7527     закононарушение-NOUN -0.725   127     закононарушение  NOUN
# 7887            пораждам-VERB -0.715   115            пораждам  VERB
# 7507          инфлационен-ADJ -0.696   128         инфлационен   ADJ
# 7242          предизвикам-ADJ -0.695   137         предизвикам   ADJ
# 5217          вследствие-NOUN -0.687   253          вследствие  NOUN
# 7905          безхаберие-NOUN -0.679   114          безхаберие  NOUN
# 6852              повред-NOUN -0.678   153              повред  NOUN
# 3178              авария-NOUN -0.677   595              авария  NOUN
# 4168             умишлено-ADV -0.677   373            умишлено   ADV
# 4848       пораждам-(се)-VERB -0.674   290       пораждам-(се)  VERB
# 8361          форсмажорен-ADJ -0.662   103         форсмажорен   ADJ
# 2414      вследствие-(на)-ADP -0.655   912     вследствие-(на)   ADP
# 3176          констатирам-ADJ -0.653   596         констатирам   ADJ
# 5587              зараза-NOUN -0.652   222              зараза  NOUN
# 7680               ужасен-ADJ -0.652   122              ужасен   ADJ
# 6887             бързане-NOUN -0.643   151             бързане  NOUN
# 5564             причиня-VERB -0.640   224             причиня  VERB
# 7914           ескалирам-VERB -0.640   114           ескалирам  VERB
# 7147     недофинансиране-NOUN -0.638   141     недофинансиране  NOUN
# 7636           неплащане-NOUN -0.636   123           неплащане  NOUN
# 7121        ужасявам-(се)-ADJ -0.634   142       ужасявам-(се)   ADJ
# 5478               порок-NOUN -0.634   231               порок  NOUN
# 5112           неточност-NOUN -0.623   263           неточност  NOUN
# 5992     некомпетентност-NOUN -0.623   196     некомпетентност  NOUN
# 6809            довеждам-VERB -0.623   154            довеждам  VERB
# 5844           непълнота-NOUN -0.621   205           непълнота  NOUN
# 3353             възникна-ADJ -0.617   539            възникна   ADJ
# 6668         преодолявам-VERB -0.616   161         преодолявам  VERB
# 3810             явление-NOUN -0.611   436             явление  NOUN
# 4727              тотален-ADJ -0.611   304             тотален   ADJ
# 3186             настъпя-VERB -0.609   592             настъпя  VERB
# 5064              причиня-ADJ -0.599   268             причиня   ADJ
# 3005             избегна-VERB -0.599   655             избегна  VERB
# 7237           настъпвам-VERB -0.598   137           настъпвам  VERB
# 6218        нанасям-(се)-VERB -0.594   183        нанасям-(се)  VERB
# 3991              умишлен-ADJ -0.591   403             умишлен   ADJ
# 5501               доведа-ADJ -0.591   229              доведа   ADJ
# 7618      предотвратявам-VERB -0.591   124      предотвратявам  VERB
# 5684         изкривяване-NOUN -0.590   216         изкривяване  NOUN
# 5961              телесен-ADJ -0.586   198             телесен   ADJ
# 1915         констатирам-VERB -0.586  1279         констатирам  VERB
# 7191         породя-(се)-VERB -0.583   139         породя-(се)  VERB
# 3617                 явен-ADJ -0.580   475                явен   ADJ
# 4725              настъпя-ADJ -0.578   304             настъпя   ADJ
# 5338            неяснота-NOUN -0.577   243            неяснота  NOUN
# 3464         предотвратя-VERB -0.574   511         предотвратя  VERB
# 7385             феномен-NOUN -0.573   132             феномен  NOUN
# 3244              кражба-NOUN -0.570   572              кражба  NOUN
# 4404             изпадна-VERB -0.564   342             изпадна  VERB
# 4772             хроничен-ADJ -0.563   299            хроничен   ADJ
# 7432           блокиране-NOUN -0.560   130           блокиране  NOUN
# 7973             цензура-NOUN -0.558   113             цензура  NOUN
# 4131             лобистки-ADJ -0.555   379            лобистки   ADJ
# 6643      прикривам-(се)-VERB -0.552   162      прикривам-(се)  VERB
# 6898       поправям-(се)-VERB -0.552   151       поправям-(се)  VERB
# 6856            преживея-VERB -0.548   153            преживея  VERB
# 3552         бездействие-NOUN -0.548   488         бездействие  NOUN
# 6988             брутален-ADJ -0.547   147            брутален   ADJ
# 4264             изпадам-VERB -0.545   360             изпадам  VERB
# 6530             хибриден-ADJ -0.544   168            хибриден   ADJ
# 3494          наводнение-NOUN -0.541   503          наводнение  NOUN
# 5912           прекомерен-ADJ -0.532   201          прекомерен   ADJ
# 8390              неяснот-ADJ -0.532   102             неяснот   ADJ
# 8436            смесване-NOUN -0.528   101            смесване  NOUN
# 8179         безпринципен-ADJ -0.525   107        безпринципен   ADJ
# 5996            празнота-NOUN -0.525   196            празнота  NOUN
# 5269              тотално-ADV -0.524   249             тотално   ADV
# 3377          възникване-NOUN -0.522   533          възникване  NOUN
# 6366              забава-NOUN -0.518   175              забава  NOUN
# 7808        задлъжнялост-NOUN -0.516   118        задлъжнялост  NOUN
# 4960            драстичен-ADJ -0.516   278           драстичен   ADJ
# 3995               вирус-NOUN -0.514   402               вирус  NOUN
# 5266          необоснован-ADJ -0.513   249         необоснован   ADJ
# 5824                 куп-NOUN -0.511   206                 куп  NOUN
# 2901              деяние-NOUN -0.510   693              деяние  NOUN
# 4283          вероятност-NOUN -0.509   357          вероятност  NOUN
# 5609    отстранявам-(се)-VERB -0.508   221    отстранявам-(се)  VERB
# 2387          корупционен-ADJ -0.508   925         корупционен   ADJ
# 6352            маловажен-ADJ -0.507   176           маловажен   ADJ
# 7470         заблуждение-NOUN -0.503   129         заблуждение  NOUN
# 2284         последствие-NOUN -0.503   979         последствие  NOUN
# 4684            естество-NOUN -0.502   309            естество  NOUN
# 6656          безобразие-NOUN -0.500   161          безобразие  NOUN
# 7984             гранича-VERB -0.499   112             гранича  VERB
# 7920                каша-NOUN -0.499   114                каша  NOUN
# 7460          сътресение-NOUN -0.499   130          сътресение  NOUN
# 3717               търпя-VERB -0.498   454               търпя  VERB
# 5740            избягвам-VERB -0.498   212            избягвам  VERB
# 7481            пазарлък-NOUN -0.497   129            пазарлък  NOUN
# 7375             подмина-VERB -0.496   132             подмина  VERB
# 4315   задълбочавам-(се)-VERB -0.494   353   задълбочавам-(се)  VERB
# 6479              мантра-NOUN -0.493   170              мантра  NOUN
# 4555                 меко-ADV -0.492   322                меко   ADV
# 7171           пандемичен-ADJ -0.491   140          пандемичен   ADJ
# 1417           последица-NOUN -0.490  1946           последица  NOUN
# 5422           африкански-ADJ -0.489   235          африкански   ADJ
# 3034              порочен-ADJ -0.489   644             порочен   ADJ
# 5295            претърпя-VERB -0.488   246            претърпя  VERB
# 7560          понастоящем-ADV -0.487   126         понастоящем   ADV
# 7878              заболея-ADJ -0.486   115             заболея   ADJ
# 5514          непредвиден-ADJ -0.486   228         непредвиден   ADJ
# 7547             атентат-NOUN -0.485   126             атентат  NOUN
# 7044           доплащане-NOUN -0.485   145           доплащане  NOUN
# 7781              падане-NOUN -0.485   119              падане  NOUN
# 3257               фалит-NOUN -0.483   569               фалит  NOUN
# 8429        политизиране-NOUN -0.483   101        политизиране  NOUN
# 4116         нанеса-(се)-VERB -0.482   383         нанеса-(се)  VERB
# 6160           толерирам-VERB -0.481   186           толерирам  VERB
# 7563          рестрикция-NOUN -0.480   126          рестрикция  NOUN
# 3922        предизвиквам-VERB -0.480   413        предизвиквам  VERB
# 6008  неравнопоставеност-NOUN -0.478   195  неравнопоставеност  NOUN
# 4884               срамен-ADJ -0.477   286              срамен   ADJ
# 4049          продължавам-ADJ -0.476   393         продължавам   ADJ
# 5864            произвол-NOUN -0.475   204            произвол  NOUN
# 6245              грабеж-NOUN -0.474   181              грабеж  NOUN
# 7272                 теч-NOUN -0.474   136                 теч  NOUN
# 7795        смущавам-(се)-ADJ -0.474   119       смущавам-(се)   ADJ
# 4224          настъпване-NOUN -0.472   366          настъпване  NOUN
# 7045        идентифицирам-ADJ -0.472   145       идентифицирам   ADJ
# 6195              породя-VERB -0.472   184              породя  VERB
# 7512        прикрия-(се)-VERB -0.471   128        прикрия-(се)  VERB
# 8432     разигравам-(се)-VERB -0.471   101     разигравам-(се)  VERB
# 6608                 уви-INTJ -0.470   164                 уви  INTJ
# 4853       внушавам-(си)-VERB -0.468   289       внушавам-(си)  VERB
# 6745       пренасям-(се)-VERB -0.468   157       пренасям-(се)  VERB
# 4198            епидемия-NOUN -0.466   369            епидемия  NOUN
# 7681            унижение-NOUN -0.465   122            унижение  NOUN
# 8199       обезпокоителен-ADJ -0.465   107      обезпокоителен   ADJ
# 7193               поява-NOUN -0.464   139               поява  NOUN
# 7993            измислям-VERB -0.462   112            измислям  VERB
# 2567            възникна-VERB -0.461   826            възникна  VERB
# 5512          натрупване-NOUN -0.460   228          натрупване  NOUN
# 4642              заразен-ADJ -0.459   313             заразен   ADJ
# 8298            необратим-ADJ -0.458   104           необратим   ADJ
# 6006             колизия-NOUN -0.458   195             колизия  NOUN
# 7495      безотговорност-NOUN -0.456   128      безотговорност  NOUN
# 8144        обезлюдяване-NOUN -0.449   108        обезлюдяване  NOUN
# 7815              нанесен-ADJ -0.448   118             нанесен   ADJ
# 4673          неефективен-ADJ -0.448   310         неефективен   ADJ
# 8308       противозаконен-ADJ -0.447   104      противозаконен   ADJ
# 7290         минимизирам-VERB -0.446   135         минимизирам  VERB
# 3102              допусна-ADJ -0.445   619             допусна   ADJ
# 2560      несъответствие-NOUN -0.444   830      несъответствие  NOUN
# 4440    незаконосъобразен-ADJ -0.444   337   незаконосъобразен   ADJ
# 4800       безпрецедентен-ADJ -0.443   295      безпрецедентен   ADJ
# 5046         несигурност-NOUN -0.443   270         несигурност  NOUN
# 5440         неразбиране-NOUN -0.443   234         неразбиране  NOUN
# 7213      несъвършенство-NOUN -0.443   138      несъвършенство  NOUN
# 4504           дисбаланс-NOUN -0.442   329           дисбаланс  NOUN
# 6724        констатиране-NOUN -0.441   158        констатиране  NOUN
# 4295            убийство-NOUN -0.437   356            убийство  NOUN
# 2209           фактически-ADJ -0.437  1037          фактически   ADJ
# 6027          съкращение-NOUN -0.437   194          съкращение  NOUN
# 4594           несериозен-ADJ -0.433   318          несериозен   ADJ
# 5115           премахвам-VERB -0.432   263           премахвам  VERB
# 3885         коронавирус-NOUN -0.431   420         коронавирус  NOUN
# 4563             лобизъм-NOUN -0.429   321             лобизъм  NOUN
# 5983           влошаване-NOUN -0.429   196           влошаване  NOUN
# 6876          недоумение-NOUN -0.428   152          недоумение  NOUN
# 3483       неблагоприятен-ADJ -0.428   506      неблагоприятен   ADJ
# 6711           популация-NOUN -0.428   159           популация  NOUN
# 6101           дублиране-NOUN -0.427   189           дублиране  NOUN
# 6593            доктрина-NOUN -0.427   164            доктрина  NOUN
# 2379             пропуск-NOUN -0.426   928             пропуск  NOUN
# 4458         появявам-се-VERB -0.425   335         появявам-се  VERB
# 5072                рязък-ADJ -0.424   267               рязък   ADJ
# 1927         злоупотреба-NOUN -0.423  1265         злоупотреба  NOUN
# 7657             вероятен-ADJ -0.421   122            вероятен   ADJ
# 5716        нестабилност-NOUN -0.420   214        нестабилност  NOUN
# 4129      предупреждавам-VERB -0.420   380      предупреждавам  VERB
# 4977              огнище-NOUN -0.420   277              огнище  NOUN
# 6527            свлачищен-ADJ -0.419   168           свлачищен   ADJ
# 7169              неточен-ADJ -0.419   140             неточен   ADJ
# 8408         частноправен-ADJ -0.418   102        частноправен   ADJ
# 6024          провокация-NOUN -0.416   194          провокация  NOUN
# 7582         налагам-(се)-ADJ -0.416   125        налагам-(се)   ADJ
# 7181             бедствен-ADJ -0.416   139            бедствен   ADJ
# 7052           случа-(се)-ADJ -0.415   145          случа-(се)   ADJ
# 3830     несправедливост-NOUN -0.415   431     несправедливост  NOUN
# 6454              изрека-VERB -0.415   171              изрека  VERB
# 1949            забавяне-NOUN -0.414  1247            забавяне  NOUN
# 7873                гето-NOUN -0.414   115                гето  NOUN
# 6435          задействам-VERB -0.413   172          задействам  VERB
# 2011     разпространение-NOUN -0.412  1194     разпространение  NOUN
# 6801           репресирам-ADJ -0.412   155          репресирам   ADJ
# 8352           пренасяне-NOUN -0.411   103           пренасяне  NOUN
# 8102           задкулисен-ADJ -0.411   109          задкулисен   ADJ
# 6148       заболеваемост-NOUN -0.410   186       заболеваемост  NOUN
# 6729         безконтролен-ADJ -0.409   157        безконтролен   ADJ
# 3283           следствие-NOUN -0.408   561           следствие  NOUN
# 7882        недокомплект-NOUN -0.408   115        недокомплект  NOUN
# 5591             нелоялен-ADJ -0.407   222            нелоялен   ADJ
# 8152       поддавам-(се)-VERB -0.407   108       поддавам-(се)  VERB
# 7196             пропаст-NOUN -0.407   139             пропаст  NOUN
# 3640            репресия-NOUN -0.406   467            репресия  NOUN
# 5140            неистина-NOUN -0.402   260            неистина  NOUN
# 7965    разпространя-(се)-ADJ -0.401   113   разпространя-(се)   ADJ
# 4327          овладяване-NOUN -0.401   352          овладяване  NOUN
# 5836           драматичен-ADJ -0.401   205          драматичен   ADJ
# 7749             симптом-NOUN -0.399   120             симптом  NOUN
# 7650             узаконя-VERB -0.399   123             узаконя  VERB
# 7664            крайност-NOUN -0.399   122            крайност  NOUN
# 5644           неизвестен-ADJ -0.397   219          неизвестен   ADJ
# 7957          коригиране-NOUN -0.397   113          коригиране  NOUN
# 5773        идеологически-ADJ -0.396   210       идеологически   ADJ
# 7106      епидемиологичен-ADJ -0.396   142     епидемиологичен   ADJ
# 5102                риба-NOUN -0.395   264                риба  NOUN
# 6398        пренеса-(се)-VERB -0.393   174        пренеса-(се)  VERB
# 7714               терор-NOUN -0.392   121               терор  NOUN
# 8262      натрупвам-(се)-VERB -0.392   105      натрупвам-(се)  VERB
# 7554            необясним-ADJ -0.391   126           необясним   ADJ
# 7994               кабел-NOUN -0.391   112               кабел  NOUN
# 6569           съзнателно-ADV -0.391   166          съзнателно   ADV
# 6228                цирк-NOUN -0.391   183                цирк  NOUN
# 7166          конюнктурен-ADJ -0.391   140         конюнктурен   ADJ
# 7457        реабилитация-NOUN -0.390   130        реабилитация  NOUN
# 7070              паника-NOUN -0.390   144              паника  NOUN
# 5090                налик-ADJ -0.390   265               налик   ADJ
# 2260           крия-(се)-VERB -0.389   991           крия-(се)  VERB
# 5032          презумпция-NOUN -0.389   272          презумпция  NOUN
# 6498       изолирам-(се)-VERB -0.388   169       изолирам-(се)  VERB
# 4342          автоматично-ADV -0.388   349         автоматично   ADV
# 3195              странен-ADJ -0.387   590             странен   ADJ
# 5130           източване-NOUN -0.387   261           източване  NOUN
# 2919         манипулация-NOUN -0.386   688         манипулация  NOUN
# 6202      хоспитализация-NOUN -0.384   184      хоспитализация  NOUN
# 7960              нонсенс-ADJ -0.384   113             нонсенс   ADJ
# 3585             тревожен-ADJ -0.384   483            тревожен   ADJ
# 5949          елиминирам-VERB -0.384   198          елиминирам  VERB
# 8270          полуостров-NOUN -0.383   105          полуостров  NOUN
# 7170         обрека-(се)-VERB -0.382   140         обрека-(се)  VERB
# 3638                чума-NOUN -0.382   468                чума  NOUN
# 3753          изключване-NOUN -0.382   446          изключване  NOUN
# 7967             свиване-NOUN -0.381   113             свиване  NOUN
# 3986         недоволство-NOUN -0.380   403         недоволство  NOUN
# 2374          нарушаване-NOUN -0.380   932          нарушаване  NOUN
# 6830              смъртен-ADJ -0.380   154             смъртен   ADJ
# 4935                 чест-ADJ -0.379   281                чест   ADJ
# 3997           криминален-ADJ -0.379   402          криминален   ADJ
# 5785             бариера-NOUN -0.378   209             бариера  NOUN
# 4516            инфекция-NOUN -0.376   327            инфекция  NOUN
# 4376            скандален-ADJ -0.375   346           скандален   ADJ
# 4674         несправедлив-ADJ -0.375   310        несправедлив   ADJ
# 3729            поредица-NOUN -0.374   451            поредица  NOUN
# 6911              фатален-ADJ -0.374   151             фатален   ADJ
# 5572        диспропорция-NOUN -0.373   223        диспропорция  NOUN
# 8379            заяждане-NOUN -0.373   102            заяждане  NOUN
# 6156            неминуемо-ADV -0.372   186           неминуемо   ADV
# 6376          превишение-NOUN -0.371   175          превишение  NOUN
# 7500               графа-NOUN -0.370   128               графа  NOUN
# 8164             спекула-NOUN -0.370   108             спекула  NOUN
# 8159          проявление-NOUN -0.369   108          проявление  NOUN
# 3591           прецедент-NOUN -0.369   481           прецедент  NOUN
# 7883         неолиберален-ADJ -0.369   115        неолиберален   ADJ
# 4446         нередовност-NOUN -0.369   336         нередовност  NOUN
# 6154           нежелание-NOUN -0.367   186           нежелание  NOUN
# 4964            нараствам-ADJ -0.366   278           нараствам   ADJ
# 3704         терористичен-ADJ -0.365   456        терористичен   ADJ
# 2056                масов-ADJ -0.365  1155               масов   ADJ
# 7830           обобщавам-VERB -0.364   117           обобщавам  VERB
# 5497         съставлявам-VERB -0.364   230         съставлявам  VERB
# 4107     пътнотранспортен-ADJ -0.363   385    пътнотранспортен   ADJ
# 7277             движене-NOUN -0.363   135             движене  NOUN
# 4290         натоварване-NOUN -0.362   356         натоварване  NOUN
# 2552           преодолея-VERB -0.362   835           преодолея  VERB
# 4902           бавя-(се)-VERB -0.362   283           бавя-(се)  VERB
# 1919        противоречие-NOUN -0.362  1274        противоречие  NOUN
# 5628          ликвидирам-VERB -0.362   220          ликвидирам  VERB
# 4285           доказване-NOUN -0.361   357           доказване  NOUN
# 6712         предполагаем-ADJ -0.361   159        предполагаем   ADJ
# 4399           будя-(се)-VERB -0.360   342           будя-(се)  VERB
# 5726            драстично-ADV -0.359   213           драстично   ADV
# 6820             настрана-ADV -0.359   154            настрана   ADV
# 6210       задълбочаване-NOUN -0.359   183       задълбочаване  NOUN
# 5539                смес-NOUN -0.358   226                смес  NOUN
# 5538      сблъсквам-(се)-VERB -0.357   226      сблъсквам-(се)  VERB
# 4482              съставя-ADJ -0.357   332             съставя   ADJ
# 5715        неоснователен-ADJ -0.356   214       неоснователен   ADJ
# 7966               рубла-NOUN -0.356   113               рубла  NOUN
# 7588        пресека-(се)-VERB -0.356   125        пресека-(се)  VERB
# 6035              заваря-VERB -0.354   193              заваря  VERB
# 5116            проблемен-ADJ -0.354   263           проблемен   ADJ
# 1701          напрежение-NOUN -0.354  1507          напрежение  NOUN
# 8188           емиграция-NOUN -0.353   107           емиграция  NOUN
# 8105              коляно-NOUN -0.353   109              коляно  NOUN
# 2357        неизпълнение-NOUN -0.352   941        неизпълнение  NOUN
# 7734       изразявам-(се)-ADJ -0.352   120      изразявам-(се)   ADJ
# 2994               вълна-NOUN -0.351   658               вълна  NOUN
# 5876                сняг-NOUN -0.351   203                сняг  NOUN
# 2340    установявам-(се)-VERB -0.350   949    установявам-(се)  VERB
# 3806         неравенство-NOUN -0.349   436         неравенство  NOUN
# 8162       сблъскам-(се)-VERB -0.349   108       сблъскам-(се)  VERB
# 7035            риторика-NOUN -0.348   146            риторика  NOUN
# 5641       изегламентирам-ADJ -0.348   219      изегламентирам   ADJ
# 6098            спра-(се)-ADJ -0.348   190           спра-(се)   ADJ
# 7311            непосилен-ADJ -0.347   134           непосилен   ADJ
# 6062         рестриктивен-ADJ -0.347   192        рестриктивен   ADJ
# 7262     облекчавам-(се)-VERB -0.347   136     облекчавам-(се)  VERB
# 4728           уволнение-NOUN -0.347   304           уволнение  NOUN
# 1933           недопустим-ADJ -0.347  1257          недопустим   ADJ
# 4216         неправомерен-ADJ -0.346   367        неправомерен   ADJ
# 8372              горене-NOUN -0.345   102              горене  NOUN
# 5659      несъвместимост-NOUN -0.345   218      несъвместимост  NOUN
# 7953         замразя-(се)-ADJ -0.345   113        замразя-(се)   ADJ
# 2413            внушение-NOUN -0.344   912            внушение  NOUN
# 8155           превозвам-VERB -0.344   108           превозвам  VERB
# 6977          подозрение-NOUN -0.344   148          подозрение  NOUN
# 3772         преустановя-VERB -0.343   442         преустановя  VERB
# 7240              отмина-VERB -0.342   137              отмина  VERB
# 5316           унизителен-ADJ -0.342   245          унизителен   ADJ
# 7173             сметище-NOUN -0.341   140             сметище  NOUN
# 8389            неуместен-ADJ -0.340   102           неуместен   ADJ
# 5398            изненада-NOUN -0.339   237            изненада  NOUN
# 5901         водопроводен-ADJ -0.339   201        водопроводен   ADJ
# 5290         възродителен-ADJ -0.339   246        възродителен   ADJ
# 7425        фалшификация-NOUN -0.338   131        фалшификация  NOUN
# 3365            свлачище-NOUN -0.338   536            свлачище  NOUN
# 8387    националистически-ADJ -0.337   102   националистически   ADJ
# 5087           демагогия-NOUN -0.337   265           демагогия  NOUN
# 4018        притеснителен-ADJ -0.337   398       притеснителен   ADJ
# 6055           оплакване-NOUN -0.336   192           оплакване  NOUN
# 7089           колебание-NOUN -0.336   143           колебание  NOUN
# 7759         бюрократичен-ADJ -0.335   119        бюрократичен   ADJ
# 7862    преработвам-(се)-VERB -0.334   116    преработвам-(се)  VERB
# 7540            прозирам-VERB -0.334   127            прозирам  VERB
# 7214              остарея-ADJ -0.334   138             остарея   ADJ
# 6485             незнайно-ADV -0.333   170            незнайно   ADV
# 6015         разсея-(се)-VERB -0.332   195         разсея-(се)  VERB
# 6252           пресичане-NOUN -0.332   181           пресичане  NOUN
# 7485         революционен-ADJ -0.331   129        революционен   ADJ
# 2291       отстраня-(се)-VERB -0.331   973       отстраня-(се)  VERB
# 7128             вторичен-ADJ -0.331   141            вторичен   ADJ
# 5074             създавам-ADJ -0.331   267            създавам   ADJ
# 7985                дере-NOUN -0.331   112                дере  NOUN
# 8310          редуциране-NOUN -0.330   104          редуциране  NOUN
# 6026              съкратя-ADJ -0.330   194             съкратя   ADJ
# 1930           множество-NOUN -0.329  1260           множество  NOUN
# 7863            прескоча-VERB -0.329   116            прескоча  VERB
# 2708             вкарвам-VERB -0.328   771             вкарвам  VERB
# 5006                късен-ADJ -0.328   274               късен   ADJ
# 6477          заразя-(се)-ADJ -0.327   170         заразя-(се)   ADJ
# 3808         разминаване-NOUN -0.325   436         разминаване  NOUN
# 5920              недобър-ADJ -0.325   200             недобър   ADJ
# 6518               валеж-NOUN -0.325   168               валеж  NOUN
# 3470         понеса-(се)-VERB -0.324   510         понеса-(се)  VERB
# 3946           неприемлив-ADJ -0.324   409          неприемлив   ADJ
# 8077               помпа-NOUN -0.324   110               помпа  NOUN
# 2403            инцидент-NOUN -0.324   916            инцидент  NOUN
# 4781           затваряне-NOUN -0.324   297           затваряне  NOUN
# 6774         радиоактивен-ADJ -0.323   156        радиоактивен   ADJ
# 8317                трая-VERB -0.323   104                трая  VERB
# 2142             системен-ADJ -0.322  1085            системен   ADJ
# 6112            боеприпас-ADJ -0.322   188           боеприпас   ADJ
# 4750         инвалидност-NOUN -0.322   301         инвалидност  NOUN
# 4390          недопустимо-ADV -0.321   344         недопустимо   ADV
# 3349         забавя-(се)-VERB -0.321   541         забавя-(се)  VERB
# 2982           епидемичен-ADJ -0.319   664          епидемичен   ADJ
# 6038            неизбежен-ADJ -0.319   193           неизбежен   ADJ
# 2248           обвинение-NOUN -0.319  1004           обвинение  NOUN
# 7630          депониране-NOUN -0.319   123          депониране  NOUN
# 4768         деклариране-NOUN -0.318   299         деклариране  NOUN
# 6568           спестявам-VERB -0.318   166           спестявам  VERB
# 7093              печатен-ADJ -0.318   143             печатен   ADJ
# 4589             давност-NOUN -0.318   318             давност  NOUN
# 8001              пагубен-ADJ -0.317   112             пагубен   ADJ
# 3089          спекулация-NOUN -0.316   622          спекулация  NOUN
# 7586              пработя-ADJ -0.316   125             пработя   ADJ
# 2586         замърсяване-NOUN -0.315   822         замърсяване  NOUN
# 1671           твърдение-NOUN -0.315  1539           твърдение  NOUN
# 1859        преодоляване-NOUN -0.314  1337        преодоляване  NOUN
# 8137              вакуум-NOUN -0.314   108              вакуум  NOUN
# 8297          необработен-ADJ -0.314   104         необработен   ADJ
# 7517                стана-ADJ -0.314   128               стана   ADJ
# 3984              направо-ADV -0.313   403             направо   ADV
# 6972          ксенофобия-NOUN -0.313   148          ксенофобия  NOUN
# 4978             течение-NOUN -0.313   277             течение  NOUN
# 8003          понижаване-NOUN -0.312   112          понижаване  NOUN
# 7892      проработя-(се)-VERB -0.310   115      проработя-(се)  VERB
# 8420             записка-NOUN -0.310   101             записка  NOUN
# 5797         заобикаляне-NOUN -0.310   208         заобикаляне  NOUN
# 6281           постройка-NOUN -0.309   180           постройка  NOUN
# 7851                инат-NOUN -0.309   116                инат  NOUN
# 5088     дискриминационен-ADJ -0.309   265    дискриминационен   ADJ
# 7001          потенциално-ADV -0.308   147         потенциално   ADV
# 1879        отстраняване-NOUN -0.307  1310        отстраняване  NOUN
# 4254              тормоз-NOUN -0.307   362              тормоз  NOUN
# 5212           съпротива-NOUN -0.307   254           съпротива  NOUN
# 6217           навлизане-NOUN -0.306   183           навлизане  NOUN
# 6867            генерирам-ADJ -0.305   152           генерирам   ADJ
# 5721                шега-NOUN -0.305   214                шега  NOUN
# 5838       задържам-(се)-VERB -0.304   205       задържам-(се)  VERB
# 5110          ликвидация-NOUN -0.304   263          ликвидация  NOUN
# 3866              обвиня-VERB -0.303   423              обвиня  VERB
# 8261           насилствен-ADJ -0.302   105          насилствен   ADJ
# 5598                бивам-AUX -0.302   221               бивам   AUX
# 7424               тегло-NOUN -0.302   131               тегло  NOUN
# 5414    политизирам-(се)-VERB -0.302   236    политизирам-(се)  VERB
# 7796        тревожа-(се)-VERB -0.301   119        тревожа-(се)  VERB
# 4439                 леко-ADV -0.301   337                леко   ADV
# 5595           психически-ADJ -0.300   222          психически   ADJ
# 6274          комбинация-NOUN -0.300   180          комбинация  NOUN
# 8080       смущавам-(се)-VERB -0.300   110       смущавам-(се)  VERB
# 7049        повдигна-(се)-ADJ -0.299   145       повдигна-(се)   ADJ
# 7451          отложа-(се)-ADJ -0.299   130         отложа-(се)   ADJ
# 3425               дупка-NOUN -0.299   521               дупка  NOUN
# 6694             сваляне-NOUN -0.298   160             сваляне  NOUN
# 2926        произшествие-NOUN -0.298   687        произшествие  NOUN
# 5825           мигрантски-ADJ -0.298   206          мигрантски   ADJ
# 6863            укриване-NOUN -0.298   153            укриване  NOUN
# 1660            хипотеза-NOUN -0.296  1559            хипотеза  NOUN
# 1805           имуществен-ADJ -0.296  1394          имуществен   ADJ
# 5345         ликвидиране-NOUN -0.295   242         ликвидиране  NOUN
# 6691        национализъм-NOUN -0.294   160        национализъм  NOUN
# 5735           белодробен-ADJ -0.294   212          белодробен   ADJ
# 6302                  сух-ADJ -0.294   179                 сух   ADJ
# 5980              химичен-ADJ -0.294   197             химичен   ADJ
# 6665                  ков-ADJ -0.293   161                 ков   ADJ
# 5114             повторно-ADV -0.292   263            повторно   ADV
# 4626              непълен-ADJ -0.292   315             непълен   ADJ
# 8289              джипка-NOUN -0.291   104              джипка  NOUN
# 5870       засилвам-(се)-VERB -0.291   203       засилвам-(се)  VERB
# 4608          оправдание-NOUN -0.291   317          оправдание  NOUN
# 3895       посегателство-NOUN -0.290   418       посегателство  NOUN
# 5719            парадокс-NOUN -0.290   214            парадокс  NOUN
# 4688             осъждам-VERB -0.290   309             осъждам  VERB
# 8437               убиец-NOUN -0.290   101               убиец  NOUN
# 7074      редуцирам-(се)-VERB -0.290   144      редуцирам-(се)  VERB
# 4043               пожар-NOUN -0.288   394               пожар  NOUN
# 7105       енергоносител-NOUN -0.288   142       енергоносител  NOUN
# 3022               ковид-NOUN -0.288   651               ковид  NOUN
# 5871           злополука-NOUN -0.288   203           злополука  NOUN
# 5207              картел-NOUN -0.288   254              картел  NOUN
# 3598        санкционирам-VERB -0.288   479        санкционирам  VERB
# 4075        ограничителен-ADJ -0.288   389       ограничителен   ADJ
# 1503            незаконен-ADJ -0.287  1804           незаконен   ADJ
# 951              допусна-VERB -0.285  3232             допусна  VERB
# 5146           фактически-ADV -0.284   260          фактически   ADV
# 8348         необосновано-ADV -0.284   103        необосновано   ADV
# 6747           репресивен-ADJ -0.283   157          репресивен   ADJ
# 6794        некомпетентен-ADJ -0.283   155       некомпетентен   ADJ
# 7280            ерп-тата-NOUN -0.282   135            ерп-тата  NOUN
# 6996           наполовина-ADV -0.282   147          наполовина   ADV
# 6018          изоставане-NOUN -0.282   194          изоставане  NOUN
# 4809       геополитически-ADJ -0.281   294      геополитически   ADJ
# 7937          съвпадение-NOUN -0.281   114          съвпадение  NOUN
# 2397          наложа-(се)-ADJ -0.281   920         наложа-(се)   ADJ
# 4762           изследвам-VERB -0.281   300           изследвам  VERB
# 6396             погрешен-ADJ -0.281   174            погрешен   ADJ
# 7164               клише-NOUN -0.280   140               клише  NOUN
# 7022               дребно-ADJ -0.280   146              дребно   ADJ
# 7640    правно-технически-ADJ -0.280   123   правно-технически   ADJ
# 4789              взривен-ADJ -0.280   296             взривен   ADJ
# 2317         предизвикам-VERB -0.279   961         предизвикам  VERB
# 2441           възниквам-VERB -0.279   895           възниквам  VERB
# 3366           изключвам-VERB -0.279   535           изключвам  VERB
# 7662               заведа-ADJ -0.278   122              заведа   ADJ
# 4654            докладвам-ADJ -0.278   312           докладвам   ADJ
# 8143              ножица-NOUN -0.277   108              ножица  NOUN
# 7955            изваждам-VERB -0.277   113            изваждам  VERB
# 6616               нюанс-NOUN -0.277   163               нюанс  NOUN
# 7620             робство-NOUN -0.276   124             робство  NOUN
# 2451             скандал-NOUN -0.276   892             скандал  NOUN
# 6592           ден-днешен-ADJ -0.276   164          ден-днешен   ADJ
# 4108                 сеч-NOUN -0.276   385                 сеч  NOUN
# 7009              условно-ADV -0.275   147             условно   ADV
# 734         престъпление-NOUN -0.274  4347        престъпление  NOUN
# 6331                 купя-ADJ -0.274   177                купя   ADJ
# 7336          завишаване-NOUN -0.273   133          завишаване  NOUN
# 3317         недопускане-NOUN -0.273   552         недопускане  NOUN
# 8271          прикриване-NOUN -0.272   105          прикриване  NOUN
# 1257         ограничение-NOUN -0.271  2297         ограничение  NOUN
# 5634              умирам-VERB -0.271   220              умирам  VERB
# 7801             честота-NOUN -0.271   119             честота  NOUN
# 5766              спомена-ADJ -0.271   211             спомена   ADJ
# 8074             остарея-VERB -0.270   110             остарея  VERB
# 6229       четиринадесети-ADJ -0.270   183      четиринадесети   ADJ
# 6826            протичам-VERB -0.270   154            протичам  VERB
# 7535          некомплект-NOUN -0.270   127          некомплект  NOUN
# 623                заради-ADP -0.269  5140              заради   ADP
# 1959            бедствие-NOUN -0.269  1236            бедствие  NOUN
# 8167               табло-NOUN -0.268   108               табло  NOUN
# 3147               осъдя-VERB -0.268   605               осъдя  VERB
# 4341             признак-NOUN -0.268   350             признак  NOUN
# 4331    заблуждавам-(се)-VERB -0.268   351    заблуждавам-(се)  VERB
# 8254           изкуствено-ADV -0.267   105          изкуствено   ADV
# 7216         превишаване-NOUN -0.267   138         превишаване  NOUN
# 1596            вещество-NOUN -0.266  1667            вещество  NOUN
# 5065          тоталитарен-ADJ -0.266   268         тоталитарен   ADJ
# 4068           лицемерие-NOUN -0.266   390           лицемерие  NOUN
# 4428              петрол-NOUN -0.266   339              петрол  NOUN
# 5524         замразяване-NOUN -0.265   227         замразяване  NOUN
# 2922                 фон-NOUN -0.265   688                 фон  NOUN
# 7867              сумирам-ADJ -0.265   116             сумирам   ADJ
# 7062          едностранен-ADJ -0.265   144         едностранен   ADJ
# 6854          подсказвам-VERB -0.265   153          подсказвам  VERB
# 8018              анкета-NOUN -0.264   111              анкета  NOUN
# 1170            допускам-VERB -0.263  2515            допускам  VERB
# 4464           климатичен-ADJ -0.263   334          климатичен   ADJ

# %%
neg_expansion.to_csv('negative_expansion_BG.csv')

# %% [markdown]
# ### Save to file - POSITIVE

# %% [markdown]
# #### Combine seed and expansion lemmas and POS

# %%
for word in list(pos_expansion['lemma']):
    words_pos.append(word)
for postag in list(pos_expansion['pos']):
    postags_pos.append(postag)

# %% [markdown]
# #### Combine seed and expansion frequency-weighted scores)

# %%
#create scores for seed list
pos_seed_score = [1 for word in pos_list]
for score in list(pos_expansion['score']):
    pos_seed_score.append(score)

# %% [markdown]
# #### Write to file

# %%
with open('sentdict_pos_BG.txt', 'w', encoding = 'utf-8') as f: 
    for word, postag, score in zip(words_pos, postags_pos, pos_seed_score):
        f.write(word + '\t' + postag + '\t' + str(score) + '\n')

# %% [markdown]
# ### Save to file - NEGATIVE

# %% [markdown]
# #### Combine seed and expansion lemmas and POS

# %%
for word in list(neg_expansion['lemma']):
    words_neg.append(word)
for postag in list(neg_expansion['pos']):
    postags_neg.append(postag)

# %% [markdown]
# #### Combine seed and expansion frequency-weighted scores)

# %%
#create scores for seed list
neg_seed_score = [-1 for word in neg_list]
for score in list(neg_expansion['score']):
    neg_seed_score.append(score)

# %% [markdown]
# #### Write to file

# %%
with open('sentdict_neg_BG.txt', 'w', encoding = 'utf-8') as f: 
    for word, postag, score in zip(words_neg, postags_neg, neg_seed_score):
        f.write(word + '\t' + postag + '\t' + str(score) + '\n')
