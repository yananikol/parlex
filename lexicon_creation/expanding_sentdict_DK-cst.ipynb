# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Loading seed dicts

# %%
with open('positive_seed_DK_ALL_CORR.txt') as f:
    pos_dk = [line.split('\t') for line in f.readlines()][:200]

# %%
with open('negative_seed_DK_ALL.txt') as f:
    neg_dk = [line.split('\t') for line in f.readlines()][:200]

# %%
words_pos = [line[0] for line in pos_dk]
postags_pos = [line[1] for line in pos_dk]

pos_list = ["-".join(el) for el in zip(words_pos, postags_pos)]

# %%
words_neg = [line[0] for line in neg_dk]
postags_neg = [line[1] for line in neg_dk]

neg_list = ["-".join(el) for el in zip(words_neg, postags_neg)]

# %% [markdown]
# ### Loading GloVe embeddings

# %%
with open('glove/vectors.txt', 'r') as f:
    glove = [line.split('\n')[:-1] for line in f.readlines()]

# %%
glovedict = dict()

for embedding in glove:
    split = embedding[0].split(" ")
    glovedict[split[0]] = [float(number) for number in split[1:]]

# %% [markdown]
# #### Frequency dictionary for word embeddings

# %%
with open('glove/vocab.txt', 'r') as f:
    vocab = [line.split('\n')[:-1] for line in f.readlines()]

# %%
vocab_words = [line[0].split(" ")[0] for line in vocab]
vocab_freqs = [line[0].split(" ")[1] for line in vocab]

# %%
vocab_dict = dict(zip(vocab_words, vocab_freqs))

# %% [markdown]
# #### Check if seed words are in vocab - manual correction

# %%
vocab_list = [word.split('-')[0] for word in vocab_words]

# %%
vocab_words[vocab_list.index('takke')]
# Out:
# 'takke-VERB'

# %%
for word in pos_list:
    if word not in list(glovedict.keys()):
        print(word, "MISSING")

# %%
for word in neg_list:
    if word not in list(glovedict.keys()):
        print(word, "MISSING")

# %% [markdown]
# #### Create embedding arrays for positive and negative seed lists
#
# .pop() also removes those from dict in order to prevent perfect matches

# %%
embedding_list_pos = []

for word in pos_list:
    embedding_list_pos.append(glovedict.pop(word))
    
pos_array = np.array(embedding_list_pos)

# %%
embedding_list_neg = []

for word in neg_list:
    embedding_list_neg.append(glovedict.pop(word))
    
neg_array = np.array(embedding_list_neg)

# %%
glovedict.pop('<unk>');

# %% [markdown]
# #### Create GloVe array

# %%
glove_array = np.array(list(glovedict.values()))

# %%
glove_array.shape
# Out:
# (55810, 150)

# %% [markdown]
# ### Compute word scores

# %%
num_seed_words = 200
pos_array = pos_array[:num_seed_words]
neg_array = neg_array[:num_seed_words]

# %%
M_p = glove_array @ pos_array.T 
M_n = glove_array @ neg_array.T

# %%
shape = glove_array.shape

# %%
L_p = (np.linalg.norm(glove_array, axis = 1).reshape([shape[0], 1])) * (np.linalg.norm(pos_array, axis = 1))
L_n = (np.linalg.norm(glove_array, axis = 1).reshape([shape[0], 1])) * (np.linalg.norm(neg_array, axis = 1))

# %%
P = np.sum(M_p / L_p, axis = 1)
Q = np.sum(M_n / L_n, axis = 1)

# %%
S_i = P - Q

# %% [markdown]
# ### Find top and bottom words

# %%
#normalize scores
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler((-1, 1))
norm_score = scaler.fit_transform(S_i.reshape(-1, 1)).flatten()

# %%
words = np.array([list(glovedict.keys())]).flatten()
freqs = [int(vocab_dict[word]) for word in words]

df = pd.DataFrame({'word': words, 'score':norm_score, 'freq': freqs})

# %%
#frequency limits
df = df[df['freq'] < 15000]
df = df[df['freq'] > 100]

# %%
#splitting word column into lemma and pos columns
df[['lemma', 'pos']] = df['word'].str.split(r'\-+(?=[A-Z])', regex = True, expand = True)

# %%
#filterning out numbers, proper nouns and punctuation
df = df[df['pos'] != 'NUM']
df = df[df['pos'] != 'PROPN']
df = df[df['pos'] != 'PUNCT']
df = df[df['lemma'].str.isnumeric() == False]

# %%
#sorting by score 
sorted_df = df.sort_values(['score'])

# %% [markdown]
# ### Positive expansion

# %%
pos_expansion = sorted_df[-500:].iloc[::-1]

# %%
with pd.option_context('display.max_rows', None,
                       'display.max_columns', None,
                       'display.precision', 3,
                       ):
    print(pos_expansion)
# Out:
#                              word  score   freq                   lemma    pos
# 474                    takke-VERB  1.000   7866                   takke   VERB
# 341               samarbejde-NOUN  0.972  11703              samarbejde   NOUN
# 457                    glæde-VERB  0.964   8086                   glæde   VERB
# 4925          repræsentation-NOUN  0.928    285          repræsentation   NOUN
# 674                   levere-VERB  0.915   5013                  levere   VERB
# 2019                     flot-ADJ  0.914   1143                    flot    ADJ
# 1122                kvittere-VERB  0.891   2606                kvittere   VERB
# 629                opbakning-NOUN  0.885   5429               opbakning   NOUN
# 1204                   dejlig-ADJ  0.877   2359                  dejlig    ADJ
# 1130                 tilbyde-VERB  0.863   2567                 tilbyde   VERB
# 347                    sikker-ADJ  0.840  11622                  sikker    ADJ
# 2695                tillykke-INTJ  0.839    739                tillykke   INTJ
# 1419             kvalificere-VERB  0.835   1893             kvalificere   VERB
# 1017              samarbejde-VERB  0.832   2939              samarbejde   VERB
# 1552                 udmærket-ADJ  0.830   1673                udmærket    ADJ
# 1485              konstruktiv-ADJ  0.823   1793             konstruktiv    ADJ
# 806                     bedst-ADV  0.819   3982                   bedst    ADV
# 1190                 tilfreds-ADJ  0.816   2390                tilfreds    ADJ
# 1007                      lig-ADJ  0.816   2963                     lig    ADJ
# 2645                    solid-ADJ  0.813    761                   solid    ADJ
# 4763              allerbedste-ADJ  0.808    300             allerbedste    ADJ
# 467                   fortsat-ADV  0.805   7951                 fortsat    ADV
# 591                 velkommen-ADJ  0.802   5947               velkommen    ADJ
# 479                    sørge-VERB  0.794   7681                   sørge   VERB
# 4859                hjertelig-ADV  0.792    291               hjertelig    ADV
# 569               prioritere-VERB  0.792   6130              prioritere   VERB
# 415                    ønske-NOUN  0.791   9083                   ønske   NOUN
# 1235                  bevare-VERB  0.791   2275                  bevare   VERB
# 725                  fremmest-ADJ  0.790   4615                fremmest    ADJ
# 1012                  nordisk-ADJ  0.787   2947                 nordisk    ADJ
# 540                   dialog-NOUN  0.780   6615                  dialog   NOUN
# 1961                fleksibel-ADJ  0.776   1194               fleksibel    ADJ
# 4211                     kvit-ADJ  0.774    365                    kvit    ADJ
# 742              understøtte-VERB  0.767   4473             understøtte   VERB
# 1585                   herfra-ADV  0.767   1611                  herfra    ADV
# 3501               ligeværdig-ADJ  0.765    490              ligeværdig    ADJ
# 6831                 kvitter-NOUN  0.764    165                 kvitter   NOUN
# 321                     altid-ADV  0.763  12715                   altid    ADV
# 871                   fremme-VERB  0.759   3592                  fremme   VERB
# 5674               fantastisk-ADV  0.754    225              fantastisk    ADV
# 484                    model-NOUN  0.750   7534                   model   NOUN
# 622                drøftelse-NOUN  0.749   5582               drøftelse   NOUN
# 1081                spændende-ADJ  0.747   2700               spændende    ADJ
# 2218                 bidrage-NOUN  0.746   1008                 bidrage   NOUN
# 374                   styrke-VERB  0.746  10611                  styrke   VERB
# 316                   positiv-ADJ  0.744  12943                 positiv    ADJ
# 751                 ambition-NOUN  0.739   4390                ambition   NOUN
# 2085                 tilsagn-NOUN  0.737   1092                 tilsagn   NOUN
# 477                  bidrage-VERB  0.737   7689                 bidrage   VERB
# 439                    plads-NOUN  0.733   8453                   plads   NOUN
# 362                      bred-ADJ  0.731  11112                    bred    ADJ
# 1566                    gode-NOUN  0.731   1641                    gode   NOUN
# 2840              fremragende-ADJ  0.729    675             fremragende    ADJ
# 1138                     højt-ADV  0.727   2548                    højt    ADV
# 1082                   dygtig-ADJ  0.727   2696                  dygtig    ADJ
# 5084           fremtidssikre-VERB  0.726    269           fremtidssikre   VERB
# 724                    kunne-VERB  0.725   4630                   kunne   VERB
# 498               naturligvis-ADV  0.725   7318             naturligvis    ADV
# 582                   drøfte-VERB  0.721   6009                  drøfte   VERB
# 890                   tilbud-NOUN  0.715   3523                  tilbud   NOUN
# 1618                   værdig-ADJ  0.715   1564                  værdig    ADJ
# 6233           mellemstatslig-ADJ  0.714    193          mellemstatslig    ADJ
# 389                    bakke-VERB  0.714   9888                   bakke   VERB
# 1226            tilstrækkelig-ADJ  0.713   2294           tilstrækkelig    ADJ
# 781                     bedre-ADV  0.711   4135                   bedre    ADV
# 1034             fremadrette-VERB  0.710   2887             fremadrette   VERB
# 421                    ramme-NOUN  0.710   8935                   ramme   NOUN
# 3156                   input-NOUN  0.709    576                   input   NOUN
# 916                   notere-VERB  0.707   3354                  notere   VERB
# 343                    øvrigt-ADV  0.707  11676                  øvrigt    ADV
# 1827                fortjene-VERB  0.702   1317                fortjene   VERB
# 1509                     tryg-ADJ  0.701   1756                    tryg    ADJ
# 364                 ligesom-SCONJ  0.699  11003                 ligesom  SCONJ
# 759                     opnå-VERB  0.697   4329                    opnå   VERB
# 882                  gengæld-NOUN  0.693   3548                 gengæld   NOUN
# 291               konservativ-ADJ  0.693  14390             konservativ    ADJ
# 607                   således-ADV  0.692   5779                 således    ADV
# 695                   tillid-NOUN  0.692   4884                  tillid   NOUN
# 578                  fungere-VERB  0.691   6035                 fungere   VERB
# 638                forhandle-VERB  0.689   5314               forhandle   VERB
# 535               alternativ-NOUN  0.688   6658              alternativ   NOUN
# 2756             rammevilkår-NOUN  0.687    711             rammevilkår   NOUN
# 1155                     yde-VERB  0.682   2493                     yde   VERB
# 1293                    byde-VERB  0.681   2135                    byde   VERB
# 1181                  mandat-NOUN  0.681   2411                  mandat   NOUN
# 489                    passe-VERB  0.680   7458                   passe   VERB
# 432               fællesskab-NOUN  0.679   8641              fællesskab   NOUN
# 559                      råd-NOUN  0.678   6249                     råd   NOUN
# 713                     lokal-ADJ  0.678   4704                   lokal    ADJ
# 767                 kvalitet-NOUN  0.678   4246                kvalitet   NOUN
# 1831             videregående-ADJ  0.677   1313            videregående    ADJ
# 2115                 beholde-VERB  0.676   1068                 beholde   VERB
# 501                   adgang-NOUN  0.676   7240                  adgang   NOUN
# 1942                 tusinde-VERB  0.676   1214                 tusinde   VERB
# 2333                  velfærd-ADJ  0.675    938                 velfærd    ADJ
# 1271                  bidrag-NOUN  0.675   2183                  bidrag   NOUN
# 7483           videreudvikle-VERB  0.675    142           videreudvikle   VERB
# 980                forpligte-VERB  0.675   3085               forpligte   VERB
# 4117        konkurrencedygtig-ADJ  0.675    377       konkurrencedygtig    ADJ
# 830           rigsfællesskab-NOUN  0.675   3806          rigsfællesskab   NOUN
# 596                    lytte-VERB  0.673   5879                   lytte   VERB
# 3538                  tiltro-NOUN  0.673    484                  tiltro   NOUN
# 1251         velfærdssamfund-NOUN  0.673   2238         velfærdssamfund   NOUN
# 330                  formand-NOUN  0.672  12353                 formand   NOUN
# 424                    fokus-NOUN  0.671   8876                   fokus   NOUN
# 4291            nordatlantisk-ADJ  0.669    355           nordatlantisk    ADJ
# 3568              efterskole-NOUN  0.668    478              efterskole   NOUN
# 493                      idé-NOUN  0.668   7371                     idé   NOUN
# 1404              bestyrelse-NOUN  0.668   1916              bestyrelse   NOUN
# 2691                 udbygge-VERB  0.666    741                 udbygge   VERB
# 809                fastholde-VERB  0.666   3960               fastholde   VERB
# 285                      grøn-ADJ  0.666  14863                    grøn    ADJ
# 661                 resultat-NOUN  0.662   5107                resultat   NOUN
# 1429            tilkendegive-VERB  0.662   1883            tilkendegive   VERB
# 1331        folketingsmedlem-NOUN  0.661   2050        folketingsmedlem   NOUN
# 979             ordførertale-NOUN  0.661   3089            ordførertale   NOUN
# 785                    vegne-NOUN  0.660   4096                   vegne   NOUN
# 967                    stede-NOUN  0.660   3144                   stede   NOUN
# 382                 afgørende-ADJ  0.659  10141               afgørende    ADJ
# 1507                    stolt-ADJ  0.659   1758                   stolt    ADJ
# 1165                 ambitiøs-ADJ  0.659   2452                ambitiøs    ADJ
# 1420                      ret-ADJ  0.659   1893                     ret    ADJ
# 960                 rådighed-NOUN  0.658   3177                rådighed   NOUN
# 651                  balance-NOUN  0.656   5205                 balance   NOUN
# 1256                varetage-VERB  0.656   2220                varetage   VERB
# 789             forudsætning-NOUN  0.654   4068            forudsætning   NOUN
# 1257                     bud-NOUN  0.653   2215                     bud   NOUN
# 5060               tilfredse-VERB  0.652    272               tilfredse   VERB
# 6290                     indfri-X  0.651    190                  indfri      X
# 2352        vedtagelsestekst-NOUN  0.651    922        vedtagelsestekst   NOUN
# 702                      fuld-ADJ  0.649   4821                    fuld    ADJ
# 4114              fjernvarme-NOUN  0.648    377              fjernvarme   NOUN
# 1544                 positivt-ADV  0.648   1687                positivt    ADV
# 471             udgangspunkt-NOUN  0.646   7903            udgangspunkt   NOUN
# 1344                attraktiv-ADJ  0.645   2025               attraktiv    ADJ
# 5956                  stabil-NOUN  0.644    208                  stabil   NOUN
# 3470                kandidat-NOUN  0.641    495                kandidat   NOUN
# 1062                     sund-ADJ  0.641   2783                    sund    ADJ
# 1357                   lande-VERB  0.639   2009                   lande   VERB
# 1154                      vid-ADJ  0.638   2497                     vid    ADJ
# 8778      energieffektivitet-NOUN  0.638    109      energieffektivitet   NOUN
# 580                  deltage-VERB  0.637   6012                 deltage   VERB
# 405                    fælles-ADJ  0.637   9314                  fælles    ADJ
# 1951           fleksibilitet-NOUN  0.636   1206           fleksibilitet   NOUN
# 647                   niveau-NOUN  0.636   5248                  niveau   NOUN
# 304                   hjælpe-VERB  0.635  13492                  hjælpe   VERB
# 2161                    parat-ADJ  0.635   1042                   parat    ADJ
# 732                forskning-NOUN  0.634   4542               forskning   NOUN
# 616              understrege-VERB  0.634   5672             understrege   VERB
# 1270               indstille-VERB  0.634   2185               indstille   VERB
# 881                   sagtens-ADV  0.633   3549                 sagtens    ADV
# 302                   jamen-CCONJ  0.633  13603                   jamen  CCONJ
# 3366               solidarisk-ADJ  0.632    519              solidarisk    ADJ
# 1680                  lighed-NOUN  0.631   1488                  lighed   NOUN
# 486               sammenhæng-NOUN  0.630   7498              sammenhæng   NOUN
# 1153                      ro-NOUN  0.630   2502                      ro   NOUN
# 4746            inatsisartut-NOUN  0.628    302            inatsisartut   NOUN
# 1400                   pleje-VERB  0.628   1922                   pleje   VERB
# 306                    indgå-VERB  0.628  13374                   indgå   VERB
# 1873           tilrettelægge-VERB  0.626   1273           tilrettelægge   VERB
# 773                  kollega-NOUN  0.626   4193                 kollega   NOUN
# 2456               dagtilbud-NOUN  0.624    863               dagtilbud   NOUN
# 913                    stand-NOUN  0.623   3372                   stand   NOUN
# 2763             tilslutning-NOUN  0.621    710             tilslutning   NOUN
# 2518           internationalt-ADV  0.621    828          internationalt    ADV
# 2365                supplere-VERB  0.620    914                supplere   VERB
# 292                  indsats-NOUN  0.617  14261                 indsats   NOUN
# 4877            plantebasere-VERB  0.616    290            plantebasere   VERB
# 5465             lægedækning-NOUN  0.615    241             lægedækning   NOUN
# 383                initiativ-NOUN  0.612  10098               initiativ   NOUN
# 496                    ville-VERB  0.612   7347                   ville   VERB
# 900                 inddrage-VERB  0.612   3445                inddrage   VERB
# 1388                  indlæg-NOUN  0.610   1960                  indlæg   NOUN
# 6758              respektfuld-ADJ  0.610    169             respektfuld    ADJ
# 821                lejlighed-NOUN  0.609   3881               lejlighed   NOUN
# 2933                     unik-ADJ  0.609    642                    unik    ADJ
# 948                   udspil-NOUN  0.609   3224                  udspil   NOUN
# 872                      fair-ADJ  0.608   3587                    fair    ADJ
# 4999                    sikre-ADV  0.608    278                   sikre    ADV
# 822                  fremover-ADV  0.607   3879                fremover    ADV
# 868                  benytte-VERB  0.607   3614                 benytte   VERB
# 832              interessere-VERB  0.607   3774             interessere   VERB
# 1422              vejledning-NOUN  0.607   1891              vejledning   NOUN
# 1342                  grundig-ADJ  0.607   2026                 grundig    ADJ
# 4226              supplement-NOUN  0.607    363              supplement   NOUN
# 1286                fremhæve-VERB  0.607   2148                fremhæve   VERB
# 3374                bidrager-NOUN  0.606    517                bidrager   NOUN
# 1038            ligestilling-NOUN  0.606   2878            ligestilling   NOUN
# 8439           verdensklasse-NOUN  0.605    117           verdensklasse   NOUN
# 710                   optage-VERB  0.605   4744                  optage   VERB
# 2630                   oplæg-NOUN  0.605    770                   oplæg   NOUN
# 1232                 studere-VERB  0.604   2286                 studere   VERB
# 833                grønlandsk-ADJ  0.604   3761              grønlandsk    ADJ
# 1049             universitet-NOUN  0.602   2838             universitet   NOUN
# 3651             inspiration-NOUN  0.602    461             inspiration   NOUN
# 6551                indspark-NOUN  0.602    178                indspark   NOUN
# 826                 etablere-VERB  0.599   3841                etablere   VERB
# 1778            repræsentant-NOUN  0.598   1370            repræsentant   NOUN
# 3130                 økologi-NOUN  0.598    583                 økologi   NOUN
# 1158          udvalgsarbejde-NOUN  0.598   2491          udvalgsarbejde   NOUN
# 3450                 tættere-VERB  0.598    500                 tættere   VERB
# 6861             skoletilbud-NOUN  0.596    164             skoletilbud   NOUN
# 3286             partnerskab-NOUN  0.596    542             partnerskab   NOUN
# 1201                     værd-ADJ  0.595   2365                    værd    ADJ
# 6039              veluddannet-ADJ  0.595    204             veluddannet    ADJ
# 4079         opkvalificering-NOUN  0.595    383         opkvalificering   NOUN
# 2138                  vision-NOUN  0.594   1055                  vision   NOUN
# 6055                   sikret-ADV  0.594    203                  sikret    ADV
# 525                   udvalg-NOUN  0.594   6879                  udvalg   NOUN
# 2430                   satse-VERB  0.594    875                   satse   VERB
# 4839             tidssvarende-ADJ  0.593    293            tidssvarende    ADJ
# 4787                  afsøge-VERB  0.593    298                  afsøge   VERB
# 4463                gymnasial-ADJ  0.593    334               gymnasial    ADJ
# 2083                     fint-ADV  0.591   1093                    fint    ADV
# 2793             konstruktivt-ADV  0.589    697            konstruktivt    ADV
# 1705                  derimod-ADV  0.589   1452                 derimod    ADV
# 2444             iværksætter-NOUN  0.588    868             iværksætter   NOUN
# 361                     valg-NOUN  0.588  11143                    valg   NOUN
# 1128                 enighed-NOUN  0.588   2570                 enighed   NOUN
# 4623                kompetent-ADJ  0.587    315               kompetent    ADJ
# 2824              innovation-NOUN  0.587    681              innovation   NOUN
# 678                  generelt-ADV  0.587   4997                generelt    ADV
# 1922         gennemsigtighed-NOUN  0.587   1232         gennemsigtighed   NOUN
# 1213                      tæt-ADJ  0.586   2327                     tæt    ADJ
# 3344                  tættere-ADV  0.585    525                 tættere    ADV
# 999               kompetence-NOUN  0.585   3008              kompetence   NOUN
# 735                   bestemt-ADV  0.585   4524                 bestemt    ADV
# 6968               forsyning-NOUN  0.584    160               forsyning   NOUN
# 1129                   villig-ADJ  0.583   2568                  villig    ADJ
# 5734       erhvervsudvikling-NOUN  0.583    221       erhvervsudvikling   NOUN
# 5996                  måltid-NOUN  0.582    206                  måltid   NOUN
# 2340               pædagogisk-ADJ  0.581    932              pædagogisk    ADJ
# 8443               betjening-NOUN  0.581    116               betjening   NOUN
# 332            arbejdsmarked-NOUN  0.580  12221           arbejdsmarked   NOUN
# 656                    løfte-VERB  0.580   5155                   løfte   VERB
# 2142                klimalov-NOUN  0.578   1053                klimalov   NOUN
# 387                        i-PRON  0.578   9992                       i   PRON
# 433                      fast-ADV  0.577   8632                    fast    ADV
# 682                intention-NOUN  0.577   4968               intention   NOUN
# 5417        energibesparelse-NOUN  0.576    244        energibesparelse   NOUN
# 2463               tilgodese-VERB  0.576    861               tilgodese   VERB
# 8121                tillykke-NOUN  0.575    124                tillykke   NOUN
# 287                  samtidig-ADV  0.575  14674                samtidig    ADV
# 798                  tryghed-NOUN  0.575   4019                 tryghed   NOUN
# 6869                børneliv-NOUN  0.575    163                børneliv   NOUN
# 5653     professionshøjskole-NOUN  0.575    227     professionshøjskole   NOUN
# 1559                 service-NOUN  0.574   1656                 service   NOUN
# 5111            valgmulighed-NOUN  0.574    267            valgmulighed   NOUN
# 1393              overbevise-VERB  0.572   1943              overbevise   VERB
# 845                     øvrig-ADJ  0.572   3686                   øvrig    ADJ
# 7447                  tilsagn-ADV  0.571    143                 tilsagn    ADV
# 1987                     varm-ADJ  0.571   1174                    varm    ADJ
# 8632                     fin-NOUN  0.571    112                     fin   NOUN
# 1978               prioritet-NOUN  0.571   1185               prioritet   NOUN
# 1217                fokusere-VERB  0.571   2312                fokusere   VERB
# 1389                     ide-NOUN  0.570   1957                     ide   NOUN
# 634                  princip-NOUN  0.570   5371                 princip   NOUN
# 430                    særlig-ADV  0.570   8704                  særlig    ADV
# 8039       pædagoguddannelse-NOUN  0.569    126       pædagoguddannelse   NOUN
# 2106               inspirere-VERB  0.569   1073               inspirere   VERB
# 776                 opfordre-VERB  0.569   4171                opfordre   VERB
# 2948               vigtighed-NOUN  0.568    637               vigtighed   NOUN
# 1175                  venstre-ADJ  0.567   2429                 venstre    ADJ
# 4452                      tak-ADJ  0.567    336                     tak    ADJ
# 1701              opretholde-VERB  0.567   1455              opretholde   VERB
# 5486        fritidsaktivitet-NOUN  0.567    239        fritidsaktivitet   NOUN
# 6915               prisværdig-ADJ  0.567    162              prisværdig    ADJ
# 5236               inklusion-NOUN  0.566    257               inklusion   NOUN
# 1167              målsætning-NOUN  0.566   2447              målsætning   NOUN
# 7539                håndværk-NOUN  0.563    140                håndværk   NOUN
# 552                     klart-ADV  0.563   6419                   klart    ADV
# 8613                sparring-NOUN  0.563    113                sparring   NOUN
# 1423                 åbenhed-NOUN  0.563   1890                 åbenhed   NOUN
# 4753                bestræbe-VERB  0.563    301                bestræbe   VERB
# 801                     lyst-NOUN  0.562   4009                    lyst   NOUN
# 4608                   vældig-ADV  0.562    317                  vældig    ADV
# 1203            forligskreds-NOUN  0.562   2360            forligskreds   NOUN
# 397                  ordning-NOUN  0.561   9662                 ordning   NOUN
# 2129               overordne-VERB  0.560   1060               overordne   VERB
# 5677                    høje-NOUN  0.560    225                    høje   NOUN
# 355                   starte-VERB  0.560  11277                  starte   VERB
# 938                     aktiv-ADJ  0.560   3263                   aktiv    ADJ
# 800                   udvide-VERB  0.559   4013                  udvide   VERB
# 1332              præsentere-VERB  0.559   2048              præsentere   VERB
# 2252                   pleje-NOUN  0.558    984                   pleje   NOUN
# 5291                     sørg-ADJ  0.558    253                    sørg    ADJ
# 757                   spille-VERB  0.558   4337                  spille   VERB
# 1111            landdistrikt-NOUN  0.558   2636            landdistrikt   NOUN
# 1923             efterspørge-VERB  0.557   1231             efterspørge   VERB
# 7027       transportordfører-NOUN  0.557    158       transportordfører   NOUN
# 568              medarbejder-NOUN  0.557   6142             medarbejder   NOUN
# 344                       til-ADV  0.557  11671                     til    ADV
# 1424                    fond-NOUN  0.556   1889                    fond   NOUN
# 3692                   hylde-VERB  0.556    453                   hylde   VERB
# 795                fremlægge-VERB  0.555   4026               fremlægge   VERB
# 8997                   priori-ADJ  0.555    104                  priori    ADJ
# 529                  ordføre-VERB  0.555   6760                 ordføre   VERB
# 4750                    varmt-ADV  0.554    302                   varmt    ADV
# 807                    billig-ADJ  0.554   3966                  billig    ADJ
# 623               omstilling-NOUN  0.554   5548              omstilling   NOUN
# 2095                    jeres-DET  0.554   1080                   jeres    DET
# 359                       fri-ADJ  0.553  11167                     fri    ADJ
# 1219                 uddanne-VERB  0.553   2308                 uddanne   VERB
# 694                    engang-ADV  0.552   4886                  engang    ADV
# 8193                    loyal-ADJ  0.551    122                   loyal    ADJ
# 1407                invitere-VERB  0.551   1914                invitere   VERB
# 4233       samarbejdspartner-NOUN  0.551    362       samarbejdspartner   NOUN
# 4308                   nyttig-ADJ  0.549    352                  nyttig    ADJ
# 683                   utrolig-ADV  0.547   4963                 utrolig    ADV
# 797                    faglig-ADJ  0.547   4025                  faglig    ADJ
# 829                     fuldt-ADV  0.547   3815                   fuldt    ADV
# 4400             bestræbelse-NOUN  0.547    341             bestræbelse   NOUN
# 688                 derudover-ADV  0.547   4919               derudover    ADV
# 2991         selvbestemmelse-NOUN  0.547    625         selvbestemmelse   NOUN
# 824                       tæt-ADV  0.546   3872                     tæt    ADV
# 1380                       på-ADV  0.546   1973                      på    ADV
# 1484            repræsentere-VERB  0.546   1797            repræsentere   VERB
# 8320                 forsyne-VERB  0.546    119                 forsyne   VERB
# 2571                   vægte-VERB  0.546    800                   vægte   VERB
# 6582            positivliste-NOUN  0.546    177            positivliste   NOUN
# 1765                kendskab-NOUN  0.545   1383                kendskab   NOUN
# 1254                 ledelse-NOUN  0.545   2232                 ledelse   NOUN
# 5668                    team-NOUN  0.545    226                    team   NOUN
# 2800                 program-NOUN  0.545    694                 program   NOUN
# 4111                   stabil-ADJ  0.544    378                  stabil    ADJ
# 7640       uddannelsestilbud-NOUN  0.544    138       uddannelsestilbud   NOUN
# 6221                 udstrakt-ADJ  0.544    194                udstrakt    ADJ
# 328                       nå-VERB  0.544  12420                      nå   VERB
# 538                  udvikle-VERB  0.543   6624                 udvikle   VERB
# 939                       nem-ADJ  0.543   3261                     nem    ADJ
# 1067              ældrepleje-NOUN  0.542   2757              ældrepleje   NOUN
# 672         socialdemokratisk-ADJ  0.542   5027       socialdemokratisk    ADJ
# 1174                 oprette-VERB  0.542   2430                 oprette   VERB
# 664                investere-VERB  0.542   5092               investere   VERB
# 452           socialdemokrat-NOUN  0.542   8130          socialdemokrat   NOUN
# 4085                formidle-VERB  0.541    381                formidle   VERB
# 4094              hjemmeværn-NOUN  0.541    380              hjemmeværn   NOUN
# 676                 alliance-NOUN  0.541   5000                alliance   NOUN
# 5709               bibeholde-VERB  0.541    222               bibeholde   VERB
# 4145              klimavenlig-ADJ  0.541    373             klimavenlig    ADJ
# 1974              engagement-NOUN  0.540   1187              engagement   NOUN
# 2544                   afsæt-NOUN  0.540    814                   afsæt   NOUN
# 708             arbejdskraft-NOUN  0.539   4762            arbejdskraft   NOUN
# 4831                   tusind-ADJ  0.539    294                  tusind    ADJ
# 746                    viden-NOUN  0.538   4436                   viden   NOUN
# 3587     beslutningsgrundlag-NOUN  0.538    474     beslutningsgrundlag   NOUN
# 3119                 udforme-VERB  0.538    586                 udforme   VERB
# 4510            tilstrækkelig-ADV  0.537    328           tilstrækkelig    ADV
# 631                   vilkår-NOUN  0.535   5409                  vilkår   NOUN
# 2897                      vor-DET  0.535    654                     vor    DET
# 1139                 tydeligt-ADV  0.535   2541                tydeligt    ADV
# 1976              folkestyre-NOUN  0.535   1186              folkestyre   NOUN
# 2356               mobilitet-NOUN  0.535    920               mobilitet   NOUN
# 534                      åben-ADJ  0.535   6659                    åben    ADJ
# 1755               alternativ-ADJ  0.535   1397              alternativ    ADJ
# 1820       regeringsgrundlag-NOUN  0.534   1325       regeringsgrundlag   NOUN
# 764                     trods-ADP  0.534   4290                   trods    ADP
# 1223                  optaget-ADJ  0.534   2296                 optaget    ADJ
# 1557        finanslovsaftale-NOUN  0.534   1663        finanslovsaftale   NOUN
# 1168               ordentligt-ADV  0.533   2444              ordentligt    ADV
# 720                  afsætte-VERB  0.533   4649                 afsætte   VERB
# 6241              valgfrihed-NOUN  0.533    193              valgfrihed   NOUN
# 875                   endelig-ADV  0.533   3581                 endelig    ADV
# 9141                produktiv-ADJ  0.533    101               produktiv    ADJ
# 1837               faglighed-NOUN  0.532   1306               faglighed   NOUN
# 1799                 glædelig-ADJ  0.530   1349                glædelig    ADJ
# 2410                   klæde-VERB  0.530    887                   klæde   VERB
# 8961         ordførerkollega-NOUN  0.530    105         ordførerkollega   NOUN
# 2113                 udmærket-ADV  0.529   1069                udmærket    ADV
# 3806            specialisere-VERB  0.529    432            specialisere   VERB
# 799                   stemme-NOUN  0.529   4013                  stemme   NOUN
# 8963            plantebaseret-ADJ  0.529    105           plantebaseret    ADJ
# 528                 europæisk-ADJ  0.529   6771               europæisk    ADJ
# 4721                  supere-VERB  0.528    305                  supere   VERB
# 5097            specialiseret-ADJ  0.528    268           specialiseret    ADJ
# 632                  relevant-ADJ  0.528   5390                relevant    ADJ
# 1777               forberede-VERB  0.528   1371               forberede   VERB
# 8357              dygtiggøre-VERB  0.527    118              dygtiggøre   VERB
# 2876                      nok-ADJ  0.526    663                     nok    ADJ
# 5618          energistyrelse-NOUN  0.526    229          energistyrelse   NOUN
# 2642                  fagligt-ADV  0.526    761                 fagligt    ADV
# 399                  fremtid-NOUN  0.526   9588                 fremtid   NOUN
# 2295              fornøjelse-NOUN  0.525    959              fornøjelse   NOUN
# 1266              respektere-VERB  0.525   2202              respektere   VERB
# 856                  forsvar-NOUN  0.525   3653                 forsvar   NOUN
# 6355      kandidatuddannelse-NOUN  0.525    187      kandidatuddannelse   NOUN
# 371                   mening-NOUN  0.525  10721                  mening   NOUN
# 6558                      nej-ADJ  0.524    178                     nej    ADJ
# 1521  uddannelsesinstitution-NOUN  0.524   1738  uddannelsesinstitution   NOUN
# 1041                   klare-VERB  0.524   2866                   klare   VERB
# 1186                  hellere-ADV  0.524   2399                 hellere    ADV
# 7762              litteratur-NOUN  0.523    134              litteratur   NOUN
# 1327  beskæftigelsesminister-NOUN  0.523   2068  beskæftigelsesminister   NOUN
# 621              institution-NOUN  0.523   5587             institution   NOUN
# 514                    huske-VERB  0.522   7057                   huske   VERB
# 517          justitsminister-NOUN  0.522   6974         justitsminister   NOUN
# 8987                     gæt-NOUN  0.522    104                     gæt   NOUN
# 8850                diskutere-ADV  0.522    107               diskutere    ADV
# 5620             forsknings--NOUN  0.522    229              forsknings   NOUN
# 737                  velfærd-NOUN  0.521   4512                 velfærd   NOUN
# 6928                  brugbar-ADJ  0.521    161                 brugbar    ADJ
# 1273               bæredygtig-ADJ  0.520   2178              bæredygtig    ADJ
# 7390         rammebetingelse-NOUN  0.520    145         rammebetingelse   NOUN
# 8051               tværfaglig-ADJ  0.520    126              tværfaglig    ADJ
# 303                     grad-NOUN  0.520  13528                    grad   NOUN
# 556                 bekræfte-VERB  0.520   6290                bekræfte   VERB
# 4705                 udstyre-VERB  0.520    306                 udstyre   VERB
# 4783                  matche-VERB  0.519    299                  matche   VERB
# 1515             indstilling-NOUN  0.519   1747             indstilling   NOUN
# 975                     begge-DET  0.519   3110                   begge    DET
# 1533                  skaffe-VERB  0.519   1718                  skaffe   VERB
# 745                     sidst-ADV  0.518   4437                   sidst    ADV
# 1736               kompromis-NOUN  0.518   1423               kompromis   NOUN
# 1151                     kort-ADV  0.517   2508                    kort    ADV
# 1221            undervisning-NOUN  0.516   2304            undervisning   NOUN
# 6809                   fornem-ADJ  0.516    166                  fornem    ADJ
# 1350             information-NOUN  0.516   2020             information   NOUN
# 3669                    kost-NOUN  0.516    458                    kost   NOUN
# 532                    bygge-VERB  0.515   6720                   bygge   VERB
# 1250                   dansk-NOUN  0.515   2240                   dansk   NOUN
# 992                 redegøre-VERB  0.514   3033                redegøre   VERB
# 3406                     ånd-NOUN  0.514    510                     ånd   NOUN
# 719              redegørelse-NOUN  0.513   4652             redegørelse   NOUN
# 6878                      ii-NOUN  0.513    163                      ii   NOUN
# 416                     hånd-NOUN  0.513   9037                    hånd   NOUN
# 6322     uddannelsesmulighed-NOUN  0.513    189     uddannelsesmulighed   NOUN
# 1866                      rar-ADJ  0.513   1277                     rar    ADJ
# 4766                     pris-ADV  0.512    300                    pris    ADV
# 3229              medlemskab-NOUN  0.512    555              medlemskab   NOUN
# 2296                    givet-ADJ  0.511    959                   givet    ADJ
# 5374                   højest-ADV  0.511    247                  højest    ADV
# 2010                     mad-NOUN  0.511   1152                     mad   NOUN
# 1132              evaluering-NOUN  0.510   2564              evaluering   NOUN
# 519                      sal-NOUN  0.510   6954                     sal   NOUN
# 1620                kollektiv-ADJ  0.509   1561               kollektiv    ADJ
# 903                   stykke-NOUN  0.509   3422                  stykke   NOUN
# 7817                  flittig-ADJ  0.509    132                 flittig    ADJ
# 9066                  udsnit-NOUN  0.509    103                  udsnit   NOUN
# 782                  tilgang-NOUN  0.508   4120                 tilgang   NOUN
# 3439                 afprøve-VERB  0.507    502                 afprøve   VERB
# 5405               mangfoldig-ADJ  0.507    245              mangfoldig    ADJ
# 1302                   lokalt-ADV  0.506   2119                  lokalt    ADV
# 3509             fremadrettet-ADV  0.506    489            fremadrettet    ADV
# 8829               modersmål-NOUN  0.505    108               modersmål   NOUN
# 7918         grunduddannelse-NOUN  0.505    129         grunduddannelse   NOUN
# 3841                   smidig-ADJ  0.504    424                  smidig    ADJ
# 3915                   størst-ADV  0.504    410                  størst    ADV
# 3377                   hilse-NOUN  0.504    517                   hilse   NOUN
# 515                 grundlag-NOUN  0.504   7037                grundlag   NOUN
# 879                    rolle-NOUN  0.504   3560                   rolle   NOUN
# 5929      forsvarssamarbejde-NOUN  0.503    209      forsvarssamarbejde   NOUN
# 650                   skridt-NOUN  0.503   5216                  skridt   NOUN
# 3822                   robust-ADJ  0.503    428                  robust    ADJ
# 2079              rådgivning-NOUN  0.503   1095              rådgivning   NOUN
# 435                 hinanden-PRON  0.503   8565                hinanden   PRON
# 1365                 indlede-VERB  0.502   1993                 indlede   VERB
# 1387               integrere-VERB  0.501   1961               integrere   VERB
# 628                  modtage-VERB  0.501   5479                 modtage   VERB
# 935                    start-NOUN  0.500   3272                   start   NOUN
# 597                demokrati-NOUN  0.500   5867               demokrati   NOUN
# 3605                  køkken-NOUN  0.500    471                  køkken   NOUN
# 700                       jo-INTJ  0.499   4843                      jo   INTJ
# 1716      erhvervsuddannelse-NOUN  0.498   1433      erhvervsuddannelse   NOUN
# 4126            kommissorium-NOUN  0.498    376            kommissorium   NOUN
# 5184                    inde-NOUN  0.497    261                    inde   NOUN
# 1391               garantere-VERB  0.497   1945               garantere   VERB
# 654                     part-NOUN  0.497   5164                    part   NOUN
# 6213             ministerråd-NOUN  0.497    194             ministerråd   NOUN
# 4578            iværksætteri-NOUN  0.497    319            iværksætteri   NOUN
# 1452                  vælger-NOUN  0.496   1843                  vælger   NOUN
# 505          forslagsstiller-NOUN  0.496   7189         forslagsstiller   NOUN
# 3764         kristendemokrat-NOUN  0.496    439         kristendemokrat   NOUN
# 2144         tilkendegivelse-NOUN  0.496   1051         tilkendegivelse   NOUN
# 3856                overordne-AUX  0.496    421               overordne    AUX
# 924                 indkalde-VERB  0.495   3322                indkalde   VERB
# 4759                  public-NOUN  0.495    301                  public   NOUN
# 475                interesse-NOUN  0.495   7778               interesse   NOUN
# 5279                  studie-NOUN  0.495    254                  studie   NOUN
# 7074        realkreditsystem-NOUN  0.495    156        realkreditsystem   NOUN
# 1430        sundhedsminister-NOUN  0.494   1881        sundhedsminister   NOUN
# 8776                     eget-ADV  0.494    109                    eget    ADV
# 390                    ellers-ADV  0.493   9866                  ellers    ADV
# 7925         landbrugsaftale-NOUN  0.493    129         landbrugsaftale   NOUN
# 5431                    base-NOUN  0.493    243                    base   NOUN
# 1877       ungdomsuddannelse-NOUN  0.492   1271       ungdomsuddannelse   NOUN
# 5606            energisystem-NOUN  0.492    230            energisystem   NOUN
# 450                    kende-VERB  0.492   8247                   kende   VERB
# 3194                 udmærke-VERB  0.491    565                 udmærke   VERB
# 1984               nogenlunde-ADV  0.491   1179              nogenlunde    ADV
# 1148                  basere-VERB  0.491   2509                  basere   VERB
# 4168          nålakkersuisut-NOUN  0.490    371          nålakkersuisut   NOUN
# 442                    mindst-ADV  0.490   8424                  mindst    ADV
# 2797               appellere-VERB  0.490    695               appellere   VERB
# 8366           gennemarbejdet-ADJ  0.489    118          gennemarbejdet    ADJ
# 5418         energiforsyning-NOUN  0.489    244         energiforsyning   NOUN
# 2355               styrkelse-NOUN  0.489    921               styrkelse   NOUN
# 4152                     ære-NOUN  0.489    372                     ære   NOUN
# 3247                  trygge-VERB  0.488    551                  trygge   VERB
# 6714             boligaftale-NOUN  0.488    170             boligaftale   NOUN
# 712                   bekendt-ADJ  0.488   4708                 bekendt    ADJ

# %%
pos_expansion.to_csv('positive_expansion_DK.csv')

# %% [markdown]
# ### Negative expansion

# %%
neg_expansion = sorted_df[:500]

# %%
with pd.option_context('display.max_rows', None,
                       'display.max_columns', None,
                       'display.precision', 3,
                       ):
    print(neg_expansion)
# Out:
#                                   word  score  freq  \
# 5968                    forårsage-VERB -0.886   207
# 4310                    utilsigtet-ADJ -0.855   352
# 7152                     eskalere-VERB -0.855   153
# 5955                  spekulation-NOUN -0.788   208
# 8488                      afværge-VERB -0.779   115
# 7688                       fyring-NOUN -0.769   136
# 7618                 komplikation-NOUN -0.760   138
# 4646                      hærværk-NOUN -0.750   312
# 7153                         fatal-ADJ -0.738   153
# 3901                oversvømmelse-NOUN -0.736   413
# 8344                 teknikalitet-NOUN -0.731   119
# 5469                     overfald-NOUN -0.720   241
# 3070                        unødig-ADJ -0.719   598
# 7086                   forældelse-NOUN -0.716   155
# 5673                      episode-NOUN -0.712   225
# 8005                    verserende-ADJ -0.700   127
# 8228                helbredsmæssig-ADJ -0.697   121
# 8429               sammenblanding-NOUN -0.694   117
# 8606                   propaganda-NOUN -0.687   113
# 7746                  beskyldning-NOUN -0.680   134
# 4932                    glidebane-NOUN -0.680   284
# 7244                  umenneskelig-ADJ -0.675   150
# 6222                  urimelighed-NOUN -0.674   194
# 3530                     decidere-VERB -0.664   484
# 8425                       røveri-NOUN -0.661   117
# 5163                   katastrofal-ADJ -0.660   263
# 4003                     hændelse-NOUN -0.659   396
# 4727                  forfølgelse-NOUN -0.659   304
# 1076                          slem-ADJ -0.658  2728
# 8089                   uhyrlighed-NOUN -0.656   125
# 8810                     vilkårlig-ADJ -0.655   109
# 8744  menneskerettighedskrænkelse-NOUN -0.655   110
# 3918                     decideret-ADJ -0.652   408
# 6649                skadevirkning-NOUN -0.647   174
# 2754                    potentielt-ADV -0.645   712
# 5921                        vrøvl-NOUN -0.643   210
# 1194                       voldsom-ADJ -0.642  2385
# 7589                     pædofili-NOUN -0.639   139
# 6586                    skattehul-NOUN -0.636   177
# 3990                        angst-NOUN -0.634   398
# 5897                    meningsløs-ADJ -0.629   211
# 2795                        absurd-ADJ -0.625   696
# 7912                coronaepidemi-NOUN -0.622   129
# 3696                       påføre-VERB -0.621   453
# 3630                      svindel-NOUN -0.621   467
# 6113                     sigtelse-NOUN -0.620   199
# 2603                        totalt-ADV -0.619   780
# 8713                  spareøvelse-NOUN -0.615   111
# 6506                    overfalde-VERB -0.614   180
# 8252                       uagtsom-ADJ -0.613   121
# 8452                      fordyre-VERB -0.610   116
# 2396               uhensigtsmæssig-ADJ -0.608   893
# 5491                 underretning-NOUN -0.605   239
# 7701                          røg-NOUN -0.604   136
# 8673                     benspænd-NOUN -0.600   111
# 8444                 bombetrussel-NOUN -0.600   116
# 6806                       derover-ADV -0.600   166
# 5624                      lovbrud-NOUN -0.598   229
# 3902                     uklarhed-NOUN -0.591   413
# 6514                   ødelæggende-ADJ -0.590   179
# 4150                     skandale-NOUN -0.589   373
# 6959                   besættelse-NOUN -0.588   160
# 9043                     nederlag-NOUN -0.583   103
# 6149                        kemisk-ADJ -0.583   197
# 7849                        bjerg-NOUN -0.583   131
# 639                       alvorlig-ADJ -0.581  5300
# 7801                   strafrabat-NOUN -0.580   133
# 1415                        farlig-ADJ -0.579  1896
# 5574                  coronavirus-NOUN -0.578   233
# 7676                       afsavn-NOUN -0.577   136
# 4871             frihedsberøvelse-NOUN -0.576   290
# 4103             utryghedsskabende-ADJ -0.575   379
# 4673                      anklage-NOUN -0.574   309
# 7712               berøringsangst-NOUN -0.572   135
# 1779                   forfærdelig-ADJ -0.571  1368
# 4397                       tyveri-NOUN -0.566   342
# 4795           uhensigtsmæssighed-NOUN -0.565   298
# 8873                    stormflod-NOUN -0.563   107
# 8181                       eu-dom-NOUN -0.562   122
# 7830                      mistænkt-ADJ -0.561   132
# 4269                     aggressiv-ADJ -0.561   357
# 5242                     ufattelig-ADJ -0.560   257
# 5958                     totalitær-ADJ -0.558   208
# 8765                 uforudsigelig-ADJ -0.556   110
# 7222                       asocial-ADJ -0.556   150
# 9106                       udbrud-NOUN -0.555   102
# 3774                      tiggeri-NOUN -0.554   438
# 4247                   uforståelig-ADJ -0.554   361
# 6352                     gigantisk-ADJ -0.554   187
# 6038                       trusle-VERB -0.552   204
# 6978              skræmmekampagne-NOUN -0.551   160
# 5566                     mutation-NOUN -0.550   234
# 9072                      begrave-VERB -0.549   102
# 5838                       afbøde-VERB -0.549   214
# 1785                   uacceptabel-ADJ -0.548  1365
# 4744                   gentagelse-NOUN -0.547   302
# 7235               misinformation-NOUN -0.546   150
# 6998                    middelhav-NOUN -0.546   159
# 8354                    bedrageri-NOUN -0.546   118
# 6994                     glyfosat-NOUN -0.546   159
# 4942                          uro-NOUN -0.543   284
# 3982             forældelsesfrist-NOUN -0.542   399
# 4736                 ghettoområde-NOUN -0.542   303
# 8756           seksualforbrydelse-NOUN -0.542   110
# 7422                       usaglig-ADJ -0.541   144
# 8604                       perron-NOUN -0.540   113
# 8249                 tilfældighed-NOUN -0.539   121
# 7722                        hugge-VERB -0.538   135
# 6020                          fejl-ADJ -0.536   204
# 2792                        havne-VERB -0.536   697
# 6182                   borgerkrig-NOUN -0.536   195
# 3699                    ubehagelig-ADJ -0.535   452
# 2673                      chikane-NOUN -0.534   747
# 7542                       kaotisk-ADJ -0.530   140
# 5099                  udemokratisk-ADJ -0.530   268
# 2320                       opdage-VERB -0.528   948
# 4611                     forværre-VERB -0.527   316
# 8436                    stopklods-NOUN -0.525   117
# 5889                      sprøjte-VERB -0.524   212
# 5474                   depression-NOUN -0.522   240
# 3459                         støj-NOUN -0.522   498
# 2904                        støde-VERB -0.521   652
# 6857                   narkotikum-NOUN -0.521   164
# 2415                       ulykke-NOUN -0.520   885
# 3673            bandekriminalitet-NOUN -0.520   457
# 3893                         viden-ADJ -0.520   415
# 8445                  cyberangreb-NOUN -0.520   116
# 4346                     ensomhed-NOUN -0.519   346
# 7148              arbejdsprøvning-NOUN -0.519   153
# 3818                  forsinkelse-NOUN -0.518   429
# 2708                    forekomme-VERB -0.518   730
# 1412                     overgreb-NOUN -0.518  1898
# 5344                        svigt-NOUN -0.517   250
# 4007                      skævhed-NOUN -0.516   396
# 8109           mistænkeliggørelse-NOUN -0.515   124
# 6201                        brutal-ADJ -0.515   194
# 2575                       uheldig-ADJ -0.511   797
# 3896               centralisering-NOUN -0.511   414
# 8358            dyrevelfærdsmæssig-ADJ -0.510   118
# 2438                   forurening-NOUN -0.510   873
# 7476                 stigmatisere-VERB -0.510   142
# 8467                   merprovenu-NOUN -0.510   116
# 7183                    særhensyn-NOUN -0.509   152
# 8808                    usympatisk-ADJ -0.509   109
# 5061                  uoverskuelig-ADJ -0.508   272
# 5575                     forfejle-VERB -0.506   233
# 7455                arbejdsulykke-NOUN -0.506   142
# 8663               sundhedsrisiko-NOUN -0.506   112
# 8620                vanvidsbilist-NOUN -0.506   113
# 6358                   korruption-NOUN -0.505   187
# 7046                  partnerdrab-NOUN -0.504   157
# 7788                   flaskehals-NOUN -0.504   133
# 6687                   manipulere-VERB -0.503   172
# 4450                   skilsmisse-NOUN -0.502   336
# 5927                     forbryde-VERB -0.502   209
# 2769                    overtræde-VERB -0.500   706
# 6167                   hjemløshed-NOUN -0.500   196
# 2192                      skadelig-ADJ -0.500  1025
# 7825                        hyppig-ADJ -0.499   132
# 2952                       udløse-VERB -0.499   636
# 6753     ministeransvarlighedslov-NOUN -0.499   169
# 4471                   fyrværkeri-NOUN -0.499   333
# 9132                konfrontation-NOUN -0.499   101
# 5477                    isolation-NOUN -0.499   240
# 5540                        virus-NOUN -0.498   236
# 7729                        mørke-NOUN -0.498   135
# 5847                     krænkende-ADJ -0.498   214
# 7939                          vold-ADJ -0.495   129
# 8297                  underforstå-VERB -0.495   120
# 3177                      uskyldig-ADJ -0.494   570
# 7443                          skør-ADJ -0.493   143
# 3934                       tragisk-ADJ -0.492   407
# 4396                       stress-NOUN -0.491   342
# 2993                     ulykkelig-ADJ -0.490   625
# 7740              samfundsproblem-NOUN -0.490   135
# 6126              kriminalisering-NOUN -0.490   198
# 8287                     slagsmål-NOUN -0.490   120
# 5019                   oprustning-NOUN -0.489   276
# 8226                    fraværende-ADJ -0.489   121
# 6527                  menneskehed-NOUN -0.489   179
# 6510                      prædike-VERB -0.488   180
# 8759            skatteplanlægning-NOUN -0.487   110
# 4572                       tåbelig-ADJ -0.486   320
# 7958                       mystisk-ADJ -0.486   128
# 6022                        håbløs-ADJ -0.486   204
# 6316                        nakke-NOUN -0.485   189
# 8614                      stemple-VERB -0.485   113
# 2539                     barriere-NOUN -0.484   817
# 6524                        lappe-VERB -0.484   179
# 3974                     relatere-VERB -0.484   401
# 8030                    karantæne-NOUN -0.483   126
# 2245                      påstand-NOUN -0.482   990
# 6685                   livstruende-ADJ -0.481   172
# 8140                        grøft-NOUN -0.479   123
# 1009                        følge-NOUN -0.478  2958
# 2629                       ekstrem-ADJ -0.477   770
# 8264                     dramatisk-ADV -0.477   120
# 8734                 euforiserende-ADJ -0.477   110
# 4973                     dødsfald-NOUN -0.475   280
# 7921              hovedbeklædning-NOUN -0.474   129
# 5596                          lag-NOUN -0.473   231
# 1931                 overtrædelse-NOUN -0.473  1225
# 8481                   underkaste-VERB -0.473   116
# 6269                         groft-ADV -0.471   191
# 4792              lovovertrædelse-NOUN -0.471   298
# 4468                         snyd-NOUN -0.469   334
# 6723            identitetspolitik-NOUN -0.469   170
# 7666                   socialisme-NOUN -0.468   137
# 7582                     forvolde-VERB -0.468   139
# 3704                      voldelig-ADJ -0.467   451
# 6209                    islamisme-NOUN -0.467   194
# 2220                   nedskæring-NOUN -0.467  1008
# 5293                        tigge-VERB -0.466   253
# 3796                kriminalisere-VERB -0.466   433
# 8251                     uafklaret-ADJ -0.466   121
# 5917                      mønster-NOUN -0.465   210
# 3086                      retorik-NOUN -0.464   595
# 741                         undgå-VERB -0.464  4481
# 4888              sikkerhedsmæssig-ADJ -0.464   289
# 2911                      imødegå-VERB -0.463   649
# 1369                      urimelig-ADJ -0.462  1990
# 6413                      udrydde-VERB -0.462   185
# 5007                     ignorere-VERB -0.462   277
# 3165                   påvirkning-NOUN -0.462   574
# 6484                     fordring-NOUN -0.461   181
# 3795              flygtningestrøm-NOUN -0.461   433
# 7877                         banal-ADJ -0.461   130
# 3048                  finanskrise-NOUN -0.460   605
# 4769                         risik-ADJ -0.459   300
# 8908                         kode-NOUN -0.459   106
# 4654                    annullere-VERB -0.459   311
# 2105                     voldtægt-NOUN -0.459  1074
# 5765                koncentration-NOUN -0.459   219
# 3197                 terrorangreb-NOUN -0.457   564
# 5764                    kemikalie-NOUN -0.457   219
# 6220              sundhedsskadelig-ADJ -0.456   194
# 8169                      skyderi-NOUN -0.455   123
# 6124                  konfrontere-VERB -0.454   198
# 5315                    chikanere-VERB -0.453   251
# 8638                    halvering-NOUN -0.452   112
# 2584                       sprede-VERB -0.451   793
# 6925                      ballade-NOUN -0.451   161
# 4599                       kronisk-ADJ -0.449   317
# 8551                        lugte-VERB -0.449   114
# 6563                       ulogisk-ADJ -0.449   178
# 6703                          knæ-NOUN -0.449   171
# 7896                     racistisk-ADJ -0.447   130
# 5680                     nedbryde-VERB -0.447   225
# 9093                    sårbarhed-NOUN -0.445   102
# 1688                       adfærd-NOUN -0.445  1478
# 4251                    overflødig-ADJ -0.445   360
# 8605                   populistisk-ADJ -0.445   113
# 3811                       kørsel-NOUN -0.444   431
# 8420                 manipulation-NOUN -0.443   117
# 4855                     udstille-VERB -0.442   292
# 9069                       ydmyge-VERB -0.442   103
# 8162                     promille-NOUN -0.442   123
# 6131                retfærdiggøre-VERB -0.441   198
# 5580                    spredning-NOUN -0.441   233
# 1726                          grov-ADJ -0.441  1430
# 849                         opstå-VERB -0.441  3677
# 7744                     udhuling-NOUN -0.440   135
# 2887                        vælte-VERB -0.440   658
# 6135                 smitterisiko-NOUN -0.439   198
# 3737                    uretfærdig-ADJ -0.439   444
# 3155                 diskriminere-VERB -0.438   576
# 6859                    præcedens-NOUN -0.438   164
# 8608                         rocker--X -0.438   113
# 2411                      konkurs-NOUN -0.438   887
# 2570                         fyre-VERB -0.438   801
# 5119           terrororganisation-NOUN -0.438   266
# 8616                          tyv-NOUN -0.437   113
# 4351           overimplementering-NOUN -0.437   346
# 8058                 butikstyveri-NOUN -0.437   125
# 5914                     invasion-NOUN -0.436   210
# 8872                  statsløshed-NOUN -0.436   107
# 6952                          akut-ADV -0.435   160
# 8854                       forker-PRON -0.434   107
# 5317                 enkeltstående-ADJ -0.434   251
# 7226                  flygtninge--NOUN -0.434   150
# 8568                   unødvendigt-ADV -0.434   114
# 2032                     utryghed-NOUN -0.433  1129
# 8209                   ubegribelig-ADJ -0.433   122
# 9032                       konflik-ADJ -0.433   103
# 5319                      gråzone-NOUN -0.433   251
# 6362                     mistænke-VERB -0.433   187
# 8222            dobbeltuddannelse-NOUN -0.433   121
# 3075                         vejr-NOUN -0.433   597
# 8954                        larme-VERB -0.432   105
# 8491                         bøde-VERB -0.432   115
# 5981                        skred-NOUN -0.432   207
# 571                          begå-VERB -0.431  6124
# 7937                     utænkelig-ADJ -0.430   129
# 6531                        puste-VERB -0.430   179
# 8339                   protestere-VERB -0.429   119
# 5875                     uhyggelig-ADJ -0.428   213
# 6435                   aktivering-NOUN -0.428   183
# 7201                     forhaste-VERB -0.428   151
# 6886                    parkering-NOUN -0.428   163
# 3133                     ideologi-NOUN -0.427   583
# 7214                  partnervold-NOUN -0.427   151
# 8227                      gevaldig-ADJ -0.427   121
# 7858                          krig-ADJ -0.427   131
# 4885                      lukning-NOUN -0.426   289
# 6984               tvangsægteskab-NOUN -0.426   160
# 8324                   hundredvis-NOUN -0.426   119
# 1936                      misbrug-NOUN -0.424  1221
# 2829                      retssag-NOUN -0.424   680
# 4670                        ukendt-ADJ -0.423   310
# 3456                      kapitel-NOUN -0.423   498
# 6365                     slagside-NOUN -0.423   187
# 3624                       ytring-NOUN -0.421   468
# 4133                     genstand-NOUN -0.420   375
# 6624               omprioritering-NOUN -0.420   175
# 7700                         pjat-NOUN -0.420   136
# 5953                  nedslidning-NOUN -0.419   208
# 5502                        storm-NOUN -0.419   238
# 3516                       grotesk-ADJ -0.419   488
# 5865      ministerbetjeningsregel-NOUN -0.418   213
# 811                       medføre-VERB -0.418  3945
# 6905                     ecigaret-NOUN -0.418   162
# 7178                   kæmpemæssig-ADJ -0.418   152
# 4011                      anklage-VERB -0.417   395
# 6881                  nedlæggelse-NOUN -0.416   163
# 8718                         uhørt-ADJ -0.416   111
# 6691                       regulær-ADJ -0.416   172
# 2090              klimaforandring-NOUN -0.415  1085
# 5326                    negligere-VERB -0.415   251
# 6555               landsforræderi-NOUN -0.414   178
# 4281                     pesticid-NOUN -0.414   356
# 2231                  forringelse-NOUN -0.414  1001
# 9087                     mørketal-NOUN -0.414   102
# 2678           forskelsbehandling-NOUN -0.413   746
# 2169                     tilstand-NOUN -0.413  1038
# 4139                      racisme-NOUN -0.413   374
# 6577                      hykleri-NOUN -0.413   177
# 6917                       skygge-NOUN -0.413   162
# 7446                   tilbageløb-NOUN -0.413   143
# 3948               skattestigning-NOUN -0.413   405
# 4933                 grænsehandel-NOUN -0.412   284
# 6077             forskelsbehandle-VERB -0.411   201
# 3714                      rygning-NOUN -0.411   449
# 6170                          lod-NOUN -0.410   196
# 8310                      bagkant-NOUN -0.410   119
# 3357                   nedlukning-NOUN -0.408   522
# 5280                vanvidskørsel-NOUN -0.408   254
# 5830             masseovervågning-NOUN -0.407   215
# 4254                    bønnekald-NOUN -0.407   359
# 8696                 kategorisere-VERB -0.407   111
# 7953                          hud-NOUN -0.406   128
# 4324                        bølge-NOUN -0.405   349
# 4185                  statsstøtte-NOUN -0.405   368
# 6427                 radikaliseret-ADJ -0.403   184
# 7998                     selvmord-NOUN -0.403   127
# 6697                        forbud-ADV -0.401   171
# 1480                         bøde-NOUN -0.401  1798
# 1259                  forbrydelse-NOUN -0.400  2210
# 8438              trusselsbillede-NOUN -0.400   117
# 8492                     beskæmme-VERB -0.400   115
# 941                           dybt-ADV -0.400  3251
# 5028                     dramatisk-ADJ -0.399   275
# 9115                           ar-NOUN -0.399   101
# 8505                 hadprædikant-NOUN -0.399   115
# 6784                      forarge-VERB -0.398   167
# 5711                   eksplodere-VERB -0.398   222
# 3185                           dum-ADJ -0.397   567
# 3039                         hund-NOUN -0.397   608
# 6752                      materiel-ADJ -0.397   169
# 6587                          svig-ADJ -0.397   177
# 4548                         hash-NOUN -0.397   323
# 6661                   legitimere-VERB -0.397   173
# 4422                         høne-NOUN -0.396   339
# 7108                       tilstå-VERB -0.396   155
# 3246                     kategori-NOUN -0.396   551
# 8681                     diabetes-NOUN -0.396   111
# 3309                     afhjælpe-VERB -0.395   532
# 5637                       rocker-NOUN -0.395   228
# 5851                   tatovering-NOUN -0.395   214
# 8733                  domfældelse-NOUN -0.395   110
# 6734                         snus-NOUN -0.395   170
# 5611                          mørk-ADJ -0.395   230
# 6000                     paradoks-NOUN -0.395   206
# 5194                    bødestraf-NOUN -0.395   260
# 7253                      betinget-ADJ -0.394   149
# 5778              afgiftsstigning-NOUN -0.394   218
# 3900               hadforbrydelse-NOUN -0.394   413
# 4817                 enkeltperson-NOUN -0.394   295
# 5404                     instruks-NOUN -0.394   245
# 6486                         hama-NOUN -0.393   181
# 6166                       grunde-VERB -0.393   196
# 7333                        talrig-ADJ -0.392   147
# 2595                      åbenlyst-ADV -0.392   787
# 5791                    foregribe-VERB -0.392   217
# 6065                         kniv-NOUN -0.391   202
# 3453                      mobning-NOUN -0.391   499
# 7262                  mindreårige-NOUN -0.390   149
# 1298                  problematisk-ADJ -0.390  2129
# 3607                       ghetto-NOUN -0.389   470
# 3985                     indgribe-VERB -0.389   399
# 8204                         prop-NOUN -0.388   122
# 6721                      hadefuld-ADJ -0.388   170
# 3484                 tilbageholde-VERB -0.388   492
# 8219                    dødsstraf-NOUN -0.387   121
# 8793                     partikel-NOUN -0.387   109
# 8878           terrorfinansiering-NOUN -0.387   107
# 6609                     stråmand-NOUN -0.387   176
# 5745                sundhedskrise-NOUN -0.387   221
# 2202                  restriktion-NOUN -0.386  1019
# 5567                  personfarlig-ADJ -0.385   234
# 3107                   indberette-VERB -0.385   588
# 2156                      køretøj-NOUN -0.385  1045
# 7037                indholdsmæssig-ADJ -0.385   157
# 6004                terrortrussel-NOUN -0.385   206
# 5036                       slukke-VERB -0.384   274
# 6554                    løftebrud-NOUN -0.384   178
# 8148                     inddæmme-VERB -0.384   123
# 6146                         gene-NOUN -0.384   197
# 6812             krigsforbrydelse-NOUN -0.383   166
# 7421                      udsving-NOUN -0.383   144
# 5128                          gen-NOUN -0.383   265
# 5509                        kanon-NOUN -0.383   237
# 6593                       aleppo-NOUN -0.382   176
# 7508                    lukkethed-NOUN -0.382   141
# 2632                     mistanke-NOUN -0.382   769
# 4518                   ulovlighed-NOUN -0.382   327
# 7416                        pande-NOUN -0.380   144
# 8805                   uforsvarlig-ADJ -0.380   109
# 8835                     sletning-NOUN -0.380   108
# 2624                           dyb-ADJ -0.380   771
# 2810                     potentiel-ADJ -0.379   690
# 2304                         civil-ADJ -0.378   955
# 1187                       psykisk-ADJ -0.378  2398
# 5310                         tåle-VERB -0.378   252
# 8368                  implikation-NOUN -0.378   118
# 5470                      stresse-VERB -0.378   241
# 6729                   nedrivning-NOUN -0.377   170
# 8260              arbejdsmiljølov-NOUN -0.377   120
# 3579                      uholdbar-ADJ -0.377   476
# 3187                    uansvarlig-ADJ -0.376   567
# 7866                 procesrisiko-NOUN -0.376   131
# 3944                        brand-NOUN -0.376   405
# 8144              hastelovgivning-NOUN -0.376   123
# 6820                         anke-NOUN -0.376   165
# 5135                 skævvridning-NOUN -0.376   265
# 5479                      symptom-NOUN -0.375   240
# 5886                  menneskeliv-NOUN -0.375   212
# 4533                      kølvand-NOUN -0.375   325
# 5272                       aflede-VERB -0.375   254
# 5651                       negativ-ADV -0.375   227
# 4816                         deraf-ADV -0.374   295
# 779                      risikere-VERB -0.374  4142
# 2146               diskrimination-NOUN -0.374  1049
# 7081           ansættelsesforhold-NOUN -0.374   155
# 3212                   systematisk-ADJ -0.373   559
# 4048                         bøvl-NOUN -0.373   389
# 3800                      strafbar-ADJ -0.373   433
# 4445                     kompleks-NOUN -0.373   336
# 5896          integrationsproblem-NOUN -0.373   211
# 9154                    vidtrække-VERB -0.373   101
# 2966                         drab-NOUN -0.372   632
# 8691                           hul-ADJ -0.371   111
# 9033                   løndumping-NOUN -0.371   103
# 1841                      indgreb-NOUN -0.370  1303
# 4570               strafskærpelse-NOUN -0.370   320
# 8555                       påtale-VERB -0.370   114
# 7316                    forsimple-VERB -0.370   147
# 9034                     ladeport-NOUN -0.370   103
# 5254                       brodden-ADJ -0.370   255
# 1665                       frygte-VERB -0.369  1506
# 3744                       genere-VERB -0.368   442
# 5129          genopdragelsesrejse-NOUN -0.367   265
# 6416                      fængsle-VERB -0.366   184
# 5516                        snige-VERB -0.366   237
# 8301                    åbenbarte-VERB -0.365   119
# 1474                         stof-NOUN -0.365  1812
# 5206               magtanvendelse-NOUN -0.365   260
# 8472                   oversvømme-VERB -0.365   116
# 8377                         mine-NOUN -0.365   118
# 3989                     tilfældig-ADJ -0.365   399
# 8924                          sjet-ADJ -0.365   106
# 7402                    aktivisme-NOUN -0.365   144
# 2943                        grave-VERB -0.365   639
# 8015                coronapandemi-NOUN -0.363   126
# 2882                       regime-NOUN -0.363   661
# 3149                       bevidst-ADV -0.362   578
# 3436                       fremmed-ADJ -0.362   503
# 8731                       brække-VERB -0.361   110
# 7368                       åbenbar-ADJ -0.361   145
# 2386                          art-NOUN -0.361   901
# 3798                     minimere-VERB -0.360   433
# 7581                       flygte-NOUN -0.360   139
# 8992                           ko-NOUN -0.360   104
# 8768                       absurd-NOUN -0.359   109
# 8275                     flygtninge--X -0.359   120
# 8573                       baglæn-NOUN -0.358   113
# 536                       udsætte-VERB -0.358  6651
# 6882                    opløsning-NOUN -0.358   163
# 2370                      lidelse-NOUN -0.358   911
# 5334                        bombe-NOUN -0.357   250
# 7018                   geopolitisk-ADJ -0.356   158
#
#                             lemma   pos
# 5968                    forårsage  VERB
# 4310                   utilsigtet   ADJ
# 7152                     eskalere  VERB
# 5955                  spekulation  NOUN
# 8488                      afværge  VERB
# 7688                       fyring  NOUN
# 7618                 komplikation  NOUN
# 4646                      hærværk  NOUN
# 7153                        fatal   ADJ
# 3901                oversvømmelse  NOUN
# 8344                 teknikalitet  NOUN
# 5469                     overfald  NOUN
# 3070                       unødig   ADJ
# 7086                   forældelse  NOUN
# 5673                      episode  NOUN
# 8005                   verserende   ADJ
# 8228               helbredsmæssig   ADJ
# 8429               sammenblanding  NOUN
# 8606                   propaganda  NOUN
# 7746                  beskyldning  NOUN
# 4932                    glidebane  NOUN
# 7244                 umenneskelig   ADJ
# 6222                  urimelighed  NOUN
# 3530                     decidere  VERB
# 8425                       røveri  NOUN
# 5163                  katastrofal   ADJ
# 4003                     hændelse  NOUN
# 4727                  forfølgelse  NOUN
# 1076                         slem   ADJ
# 8089                   uhyrlighed  NOUN
# 8810                    vilkårlig   ADJ
# 8744  menneskerettighedskrænkelse  NOUN
# 3918                    decideret   ADJ
# 6649                skadevirkning  NOUN
# 2754                   potentielt   ADV
# 5921                        vrøvl  NOUN
# 1194                      voldsom   ADJ
# 7589                     pædofili  NOUN
# 6586                    skattehul  NOUN
# 3990                        angst  NOUN
# 5897                   meningsløs   ADJ
# 2795                       absurd   ADJ
# 7912                coronaepidemi  NOUN
# 3696                       påføre  VERB
# 3630                      svindel  NOUN
# 6113                     sigtelse  NOUN
# 2603                       totalt   ADV
# 8713                  spareøvelse  NOUN
# 6506                    overfalde  VERB
# 8252                      uagtsom   ADJ
# 8452                      fordyre  VERB
# 2396              uhensigtsmæssig   ADJ
# 5491                 underretning  NOUN
# 7701                          røg  NOUN
# 8673                     benspænd  NOUN
# 8444                 bombetrussel  NOUN
# 6806                      derover   ADV
# 5624                      lovbrud  NOUN
# 3902                     uklarhed  NOUN
# 6514                  ødelæggende   ADJ
# 4150                     skandale  NOUN
# 6959                   besættelse  NOUN
# 9043                     nederlag  NOUN
# 6149                       kemisk   ADJ
# 7849                        bjerg  NOUN
# 639                      alvorlig   ADJ
# 7801                   strafrabat  NOUN
# 1415                       farlig   ADJ
# 5574                  coronavirus  NOUN
# 7676                       afsavn  NOUN
# 4871             frihedsberøvelse  NOUN
# 4103            utryghedsskabende   ADJ
# 4673                      anklage  NOUN
# 7712               berøringsangst  NOUN
# 1779                  forfærdelig   ADJ
# 4397                       tyveri  NOUN
# 4795           uhensigtsmæssighed  NOUN
# 8873                    stormflod  NOUN
# 8181                       eu-dom  NOUN
# 7830                     mistænkt   ADJ
# 4269                    aggressiv   ADJ
# 5242                    ufattelig   ADJ
# 5958                    totalitær   ADJ
# 8765                uforudsigelig   ADJ
# 7222                      asocial   ADJ
# 9106                       udbrud  NOUN
# 3774                      tiggeri  NOUN
# 4247                  uforståelig   ADJ
# 6352                    gigantisk   ADJ
# 6038                       trusle  VERB
# 6978              skræmmekampagne  NOUN
# 5566                     mutation  NOUN
# 9072                      begrave  VERB
# 5838                       afbøde  VERB
# 1785                  uacceptabel   ADJ
# 4744                   gentagelse  NOUN
# 7235               misinformation  NOUN
# 6998                    middelhav  NOUN
# 8354                    bedrageri  NOUN
# 6994                     glyfosat  NOUN
# 4942                          uro  NOUN
# 3982             forældelsesfrist  NOUN
# 4736                 ghettoområde  NOUN
# 8756           seksualforbrydelse  NOUN
# 7422                      usaglig   ADJ
# 8604                       perron  NOUN
# 8249                 tilfældighed  NOUN
# 7722                        hugge  VERB
# 6020                         fejl   ADJ
# 2792                        havne  VERB
# 6182                   borgerkrig  NOUN
# 3699                   ubehagelig   ADJ
# 2673                      chikane  NOUN
# 7542                      kaotisk   ADJ
# 5099                 udemokratisk   ADJ
# 2320                       opdage  VERB
# 4611                     forværre  VERB
# 8436                    stopklods  NOUN
# 5889                      sprøjte  VERB
# 5474                   depression  NOUN
# 3459                         støj  NOUN
# 2904                        støde  VERB
# 6857                   narkotikum  NOUN
# 2415                       ulykke  NOUN
# 3673            bandekriminalitet  NOUN
# 3893                        viden   ADJ
# 8445                  cyberangreb  NOUN
# 4346                     ensomhed  NOUN
# 7148              arbejdsprøvning  NOUN
# 3818                  forsinkelse  NOUN
# 2708                    forekomme  VERB
# 1412                     overgreb  NOUN
# 5344                        svigt  NOUN
# 4007                      skævhed  NOUN
# 8109           mistænkeliggørelse  NOUN
# 6201                       brutal   ADJ
# 2575                      uheldig   ADJ
# 3896               centralisering  NOUN
# 8358           dyrevelfærdsmæssig   ADJ
# 2438                   forurening  NOUN
# 7476                 stigmatisere  VERB
# 8467                   merprovenu  NOUN
# 7183                    særhensyn  NOUN
# 8808                   usympatisk   ADJ
# 5061                 uoverskuelig   ADJ
# 5575                     forfejle  VERB
# 7455                arbejdsulykke  NOUN
# 8663               sundhedsrisiko  NOUN
# 8620                vanvidsbilist  NOUN
# 6358                   korruption  NOUN
# 7046                  partnerdrab  NOUN
# 7788                   flaskehals  NOUN
# 6687                   manipulere  VERB
# 4450                   skilsmisse  NOUN
# 5927                     forbryde  VERB
# 2769                    overtræde  VERB
# 6167                   hjemløshed  NOUN
# 2192                     skadelig   ADJ
# 7825                       hyppig   ADJ
# 2952                       udløse  VERB
# 6753     ministeransvarlighedslov  NOUN
# 4471                   fyrværkeri  NOUN
# 9132                konfrontation  NOUN
# 5477                    isolation  NOUN
# 5540                        virus  NOUN
# 7729                        mørke  NOUN
# 5847                    krænkende   ADJ
# 7939                         vold   ADJ
# 8297                  underforstå  VERB
# 3177                     uskyldig   ADJ
# 7443                         skør   ADJ
# 3934                      tragisk   ADJ
# 4396                       stress  NOUN
# 2993                    ulykkelig   ADJ
# 7740              samfundsproblem  NOUN
# 6126              kriminalisering  NOUN
# 8287                     slagsmål  NOUN
# 5019                   oprustning  NOUN
# 8226                   fraværende   ADJ
# 6527                  menneskehed  NOUN
# 6510                      prædike  VERB
# 8759            skatteplanlægning  NOUN
# 4572                      tåbelig   ADJ
# 7958                      mystisk   ADJ
# 6022                       håbløs   ADJ
# 6316                        nakke  NOUN
# 8614                      stemple  VERB
# 2539                     barriere  NOUN
# 6524                        lappe  VERB
# 3974                     relatere  VERB
# 8030                    karantæne  NOUN
# 2245                      påstand  NOUN
# 6685                  livstruende   ADJ
# 8140                        grøft  NOUN
# 1009                        følge  NOUN
# 2629                      ekstrem   ADJ
# 8264                    dramatisk   ADV
# 8734                euforiserende   ADJ
# 4973                     dødsfald  NOUN
# 7921              hovedbeklædning  NOUN
# 5596                          lag  NOUN
# 1931                 overtrædelse  NOUN
# 8481                   underkaste  VERB
# 6269                        groft   ADV
# 4792              lovovertrædelse  NOUN
# 4468                         snyd  NOUN
# 6723            identitetspolitik  NOUN
# 7666                   socialisme  NOUN
# 7582                     forvolde  VERB
# 3704                     voldelig   ADJ
# 6209                    islamisme  NOUN
# 2220                   nedskæring  NOUN
# 5293                        tigge  VERB
# 3796                kriminalisere  VERB
# 8251                    uafklaret   ADJ
# 5917                      mønster  NOUN
# 3086                      retorik  NOUN
# 741                         undgå  VERB
# 4888             sikkerhedsmæssig   ADJ
# 2911                      imødegå  VERB
# 1369                     urimelig   ADJ
# 6413                      udrydde  VERB
# 5007                     ignorere  VERB
# 3165                   påvirkning  NOUN
# 6484                     fordring  NOUN
# 3795              flygtningestrøm  NOUN
# 7877                        banal   ADJ
# 3048                  finanskrise  NOUN
# 4769                        risik   ADJ
# 8908                         kode  NOUN
# 4654                    annullere  VERB
# 2105                     voldtægt  NOUN
# 5765                koncentration  NOUN
# 3197                 terrorangreb  NOUN
# 5764                    kemikalie  NOUN
# 6220             sundhedsskadelig   ADJ
# 8169                      skyderi  NOUN
# 6124                  konfrontere  VERB
# 5315                    chikanere  VERB
# 8638                    halvering  NOUN
# 2584                       sprede  VERB
# 6925                      ballade  NOUN
# 4599                      kronisk   ADJ
# 8551                        lugte  VERB
# 6563                      ulogisk   ADJ
# 6703                          knæ  NOUN
# 7896                    racistisk   ADJ
# 5680                     nedbryde  VERB
# 9093                    sårbarhed  NOUN
# 1688                       adfærd  NOUN
# 4251                   overflødig   ADJ
# 8605                  populistisk   ADJ
# 3811                       kørsel  NOUN
# 8420                 manipulation  NOUN
# 4855                     udstille  VERB
# 9069                       ydmyge  VERB
# 8162                     promille  NOUN
# 6131                retfærdiggøre  VERB
# 5580                    spredning  NOUN
# 1726                         grov   ADJ
# 849                         opstå  VERB
# 7744                     udhuling  NOUN
# 2887                        vælte  VERB
# 6135                 smitterisiko  NOUN
# 3737                   uretfærdig   ADJ
# 3155                 diskriminere  VERB
# 6859                    præcedens  NOUN
# 8608                       rocker     X
# 2411                      konkurs  NOUN
# 2570                         fyre  VERB
# 5119           terrororganisation  NOUN
# 8616                          tyv  NOUN
# 4351           overimplementering  NOUN
# 8058                 butikstyveri  NOUN
# 5914                     invasion  NOUN
# 8872                  statsløshed  NOUN
# 6952                         akut   ADV
# 8854                       forker  PRON
# 5317                enkeltstående   ADJ
# 7226                   flygtninge  NOUN
# 8568                  unødvendigt   ADV
# 2032                     utryghed  NOUN
# 8209                  ubegribelig   ADJ
# 9032                      konflik   ADJ
# 5319                      gråzone  NOUN
# 6362                     mistænke  VERB
# 8222            dobbeltuddannelse  NOUN
# 3075                         vejr  NOUN
# 8954                        larme  VERB
# 8491                         bøde  VERB
# 5981                        skred  NOUN
# 571                          begå  VERB
# 7937                    utænkelig   ADJ
# 6531                        puste  VERB
# 8339                   protestere  VERB
# 5875                    uhyggelig   ADJ
# 6435                   aktivering  NOUN
# 7201                     forhaste  VERB
# 6886                    parkering  NOUN
# 3133                     ideologi  NOUN
# 7214                  partnervold  NOUN
# 8227                     gevaldig   ADJ
# 7858                         krig   ADJ
# 4885                      lukning  NOUN
# 6984               tvangsægteskab  NOUN
# 8324                   hundredvis  NOUN
# 1936                      misbrug  NOUN
# 2829                      retssag  NOUN
# 4670                       ukendt   ADJ
# 3456                      kapitel  NOUN
# 6365                     slagside  NOUN
# 3624                       ytring  NOUN
# 4133                     genstand  NOUN
# 6624               omprioritering  NOUN
# 7700                         pjat  NOUN
# 5953                  nedslidning  NOUN
# 5502                        storm  NOUN
# 3516                      grotesk   ADJ
# 5865      ministerbetjeningsregel  NOUN
# 811                       medføre  VERB
# 6905                     ecigaret  NOUN
# 7178                  kæmpemæssig   ADJ
# 4011                      anklage  VERB
# 6881                  nedlæggelse  NOUN
# 8718                        uhørt   ADJ
# 6691                      regulær   ADJ
# 2090              klimaforandring  NOUN
# 5326                    negligere  VERB
# 6555               landsforræderi  NOUN
# 4281                     pesticid  NOUN
# 2231                  forringelse  NOUN
# 9087                     mørketal  NOUN
# 2678           forskelsbehandling  NOUN
# 2169                     tilstand  NOUN
# 4139                      racisme  NOUN
# 6577                      hykleri  NOUN
# 6917                       skygge  NOUN
# 7446                   tilbageløb  NOUN
# 3948               skattestigning  NOUN
# 4933                 grænsehandel  NOUN
# 6077             forskelsbehandle  VERB
# 3714                      rygning  NOUN
# 6170                          lod  NOUN
# 8310                      bagkant  NOUN
# 3357                   nedlukning  NOUN
# 5280                vanvidskørsel  NOUN
# 5830             masseovervågning  NOUN
# 4254                    bønnekald  NOUN
# 8696                 kategorisere  VERB
# 7953                          hud  NOUN
# 4324                        bølge  NOUN
# 4185                  statsstøtte  NOUN
# 6427                radikaliseret   ADJ
# 7998                     selvmord  NOUN
# 6697                       forbud   ADV
# 1480                         bøde  NOUN
# 1259                  forbrydelse  NOUN
# 8438              trusselsbillede  NOUN
# 8492                     beskæmme  VERB
# 941                          dybt   ADV
# 5028                    dramatisk   ADJ
# 9115                           ar  NOUN
# 8505                 hadprædikant  NOUN
# 6784                      forarge  VERB
# 5711                   eksplodere  VERB
# 3185                          dum   ADJ
# 3039                         hund  NOUN
# 6752                     materiel   ADJ
# 6587                         svig   ADJ
# 4548                         hash  NOUN
# 6661                   legitimere  VERB
# 4422                         høne  NOUN
# 7108                       tilstå  VERB
# 3246                     kategori  NOUN
# 8681                     diabetes  NOUN
# 3309                     afhjælpe  VERB
# 5637                       rocker  NOUN
# 5851                   tatovering  NOUN
# 8733                  domfældelse  NOUN
# 6734                         snus  NOUN
# 5611                         mørk   ADJ
# 6000                     paradoks  NOUN
# 5194                    bødestraf  NOUN
# 7253                     betinget   ADJ
# 5778              afgiftsstigning  NOUN
# 3900               hadforbrydelse  NOUN
# 4817                 enkeltperson  NOUN
# 5404                     instruks  NOUN
# 6486                         hama  NOUN
# 6166                       grunde  VERB
# 7333                       talrig   ADJ
# 2595                     åbenlyst   ADV
# 5791                    foregribe  VERB
# 6065                         kniv  NOUN
# 3453                      mobning  NOUN
# 7262                  mindreårige  NOUN
# 1298                 problematisk   ADJ
# 3607                       ghetto  NOUN
# 3985                     indgribe  VERB
# 8204                         prop  NOUN
# 6721                     hadefuld   ADJ
# 3484                 tilbageholde  VERB
# 8219                    dødsstraf  NOUN
# 8793                     partikel  NOUN
# 8878           terrorfinansiering  NOUN
# 6609                     stråmand  NOUN
# 5745                sundhedskrise  NOUN
# 2202                  restriktion  NOUN
# 5567                 personfarlig   ADJ
# 3107                   indberette  VERB
# 2156                      køretøj  NOUN
# 7037               indholdsmæssig   ADJ
# 6004                terrortrussel  NOUN
# 5036                       slukke  VERB
# 6554                    løftebrud  NOUN
# 8148                     inddæmme  VERB
# 6146                         gene  NOUN
# 6812             krigsforbrydelse  NOUN
# 7421                      udsving  NOUN
# 5128                          gen  NOUN
# 5509                        kanon  NOUN
# 6593                       aleppo  NOUN
# 7508                    lukkethed  NOUN
# 2632                     mistanke  NOUN
# 4518                   ulovlighed  NOUN
# 7416                        pande  NOUN
# 8805                  uforsvarlig   ADJ
# 8835                     sletning  NOUN
# 2624                          dyb   ADJ
# 2810                    potentiel   ADJ
# 2304                        civil   ADJ
# 1187                      psykisk   ADJ
# 5310                         tåle  VERB
# 8368                  implikation  NOUN
# 5470                      stresse  VERB
# 6729                   nedrivning  NOUN
# 8260              arbejdsmiljølov  NOUN
# 3579                     uholdbar   ADJ
# 3187                   uansvarlig   ADJ
# 7866                 procesrisiko  NOUN
# 3944                        brand  NOUN
# 8144              hastelovgivning  NOUN
# 6820                         anke  NOUN
# 5135                 skævvridning  NOUN
# 5479                      symptom  NOUN
# 5886                  menneskeliv  NOUN
# 4533                      kølvand  NOUN
# 5272                       aflede  VERB
# 5651                      negativ   ADV
# 4816                        deraf   ADV
# 779                      risikere  VERB
# 2146               diskrimination  NOUN
# 7081           ansættelsesforhold  NOUN
# 3212                  systematisk   ADJ
# 4048                         bøvl  NOUN
# 3800                     strafbar   ADJ
# 4445                     kompleks  NOUN
# 5896          integrationsproblem  NOUN
# 9154                    vidtrække  VERB
# 2966                         drab  NOUN
# 8691                          hul   ADJ
# 9033                   løndumping  NOUN
# 1841                      indgreb  NOUN
# 4570               strafskærpelse  NOUN
# 8555                       påtale  VERB
# 7316                    forsimple  VERB
# 9034                     ladeport  NOUN
# 5254                      brodden   ADJ
# 1665                       frygte  VERB
# 3744                       genere  VERB
# 5129          genopdragelsesrejse  NOUN
# 6416                      fængsle  VERB
# 5516                        snige  VERB
# 8301                    åbenbarte  VERB
# 1474                         stof  NOUN
# 5206               magtanvendelse  NOUN
# 8472                   oversvømme  VERB
# 8377                         mine  NOUN
# 3989                    tilfældig   ADJ
# 8924                         sjet   ADJ
# 7402                    aktivisme  NOUN
# 2943                        grave  VERB
# 8015                coronapandemi  NOUN
# 2882                       regime  NOUN
# 3149                      bevidst   ADV
# 3436                      fremmed   ADJ
# 8731                       brække  VERB
# 7368                      åbenbar   ADJ
# 2386                          art  NOUN
# 3798                     minimere  VERB
# 7581                       flygte  NOUN
# 8992                           ko  NOUN
# 8768                       absurd  NOUN
# 8275                   flygtninge     X
# 8573                       baglæn  NOUN
# 536                       udsætte  VERB
# 6882                    opløsning  NOUN
# 2370                      lidelse  NOUN
# 5334                        bombe  NOUN
# 7018                  geopolitisk   ADJ

# %%
neg_expansion.to_csv('negative_expansion_DK.csv')

# %% [markdown]
# ### Save to file - POSITIVE

# %% [markdown]
# #### Combine seed and expansion lemmas and POS

# %%
for word in list(pos_expansion['lemma']):
    words_pos.append(word)
for postag in list(pos_expansion['pos']):
    postags_pos.append(postag)

# %% [markdown]
# #### Combine seed and expansion frequency-weighted scores)

# %%
#create scores for seed list
pos_seed_score = [1 for word in pos_list]
for score in list(pos_expansion['score']):
    pos_seed_score.append(score)

# %% [markdown]
# #### Write to file

# %%
with open('sentdict_pos_DK.txt', 'w', encoding = 'utf-8') as f: 
    for word, postag, score in zip(words_pos, postags_pos, pos_seed_score):
        f.write(word + '\t' + postag + '\t' + str(score) + '\n')

# %% [markdown]
# ### Save to file - NEGATIVE

# %% [markdown]
# #### Combine seed and expansion lemmas and POS

# %%
for word in list(neg_expansion['lemma']):
    words_neg.append(word)
for postag in list(neg_expansion['pos']):
    postags_neg.append(postag)

# %% [markdown]
# #### Combine seed and expansion frequency-weighted scores)

# %%
#create scores for seed list
neg_seed_score = [-1 for word in neg_list]
for score in list(neg_expansion['score']):
    neg_seed_score.append(score)

# %% [markdown]
# #### Write to file

# %%
with open('sentdict_neg_DK.txt', 'w', encoding = 'utf-8') as f: 
    for word, postag, score in zip(words_neg, postags_neg, neg_seed_score):
        f.write(word + '\t' + postag + '\t' + str(score) + '\n')
